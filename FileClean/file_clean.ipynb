# %%
# ------------------------------------------
# 統計並列出所.gpx
# ------------------------------------------

from pathlib import Path
import pandas as pd

# ------------------ 參數 ------------------
TARGET_FOLDERS = {"HikingBook_gpx", "HikingNote_gpx"}
OUT_FILENAME   = "file_list.csv"          # 匯出檔名
ENCODING       = "utf-8-sig"              # Excel 友善的 UTF-8 BOM
# -----------------------------------------

def find_project_root(start: Path, targets: set[str]) -> Path:
    """
    從 start 往父層遞迴，找出同時含有所有 targets 的資料夾並回傳路徑；
    若找不到則拋出 FileNotFoundError。
    """
    for cand in [start, *start.parents]:
        if all((cand / t).exists() for t in targets):
            return cand
    raise FileNotFoundError(
        f"從 {start} 往上層都找不到同時含有 {targets} 的資料夾，"
        "請確認目錄結構是否正確。"
    )

# 1️⃣ 自動定位專案根目錄
cwd  = Path.cwd()
ROOT = find_project_root(cwd, TARGET_FOLDERS)
print(f"★ 專案根目錄：{ROOT}")

# 2️⃣ 收集檔案清單
records = []
for subdir in TARGET_FOLDERS:
    folder = ROOT / subdir
    for p in folder.iterdir():            # 不遞迴；需要遞迴改 rglob("*")
        if p.is_file():
            records.append({"folder": subdir, "filename": p.name})

if not records:
    raise RuntimeError("目標資料夾沒有掃到任何檔案，請確認路徑與檔案存在。")

# 3️⃣ 寫出 CSV 到「目前工作目錄」（cwd），方便同一 Notebook 直接讀
df = pd.DataFrame(records)
out_path = cwd / OUT_FILENAME
df.to_csv(out_path, index=False, encoding=ENCODING)

print(f"✅ 完成！共 {len(df)} 筆，已輸出 {out_path}")
# Out:
# ★ 專案根目錄：d:\_iSpan\期末專題\analyze_gpx\FileClean
# ✅ 完成！共 1108 筆，已輸出 d:\_iSpan\期末專題\analyze_gpx\FileClean\file_list.csv

# %%
# ------------------------------------------
# 工人智慧，觀察檔名決定要 保留 & 剔除 的關鍵字
# ------------------------------------------

import pandas as pd, re, pathlib

df = pd.read_csv("file_list.csv")

def normalize(name):
    stem = pathlib.Path(name).stem          # 去掉副檔名
    return re.sub(r"[^A-Za-z\u4e00-\u9fff]", "", stem)  # 只留中英文字

df["normalized"] = df["filename"].map(normalize)
df = df[df["normalized"] != ""]             # 移除被清成空字串者
result = (df.groupby(["folder", "normalized"])
            .size()
            .reset_index(name="count")
            .sort_values("count", ascending=False))

# 輸出成 CSV，方便後續分析
result.to_csv("normalized_counts.csv", index=False, encoding="utf-8-sig")
print("已輸出 normalized_counts.csv")
# Out:
# 已輸出 normalized_counts.csv

# %%
# ------------------------------------------
# 保留 536 筆 .gpx
# 剔除 572 筆 .gpx
# 將資料夾重新命名 "Clean_HikingBook_gpx", "Clean_HikingNote_gpx"
# ------------------------------------------

from pathlib import Path
import csv  # 確保已匯入 csv

# 根目錄為當前工作目錄（ANALYZE_GPX）
ROOT = Path.cwd()

# 原始要處理的資料夾
folders = ["HikingBook_gpx", "HikingNote_gpx"]

# 欲保留的關鍵字
pos_keywords = [
    "桃山",
    "桃山單攻",
    "單攻桃山",
    "桃山一日單攻",
    "一日桃山",
    "桃山步道",
]

# 欲剔除的關鍵字
neg_keywords = [
    "二", "兩", "三", "四", "未",
    "喀拉業", "喀拉頁", "喀拉葉", "喀拉曄",
    "克拉葉", "克拉業", "碦拉業", "客拉業",
    "池有", "山屋", "瀑布", "吊橋",
    "去程", "回程", "O型", "o型",
    "品田", "新達", "詩崙", "日本",
    "營地", "撤退", "下", "機車",
    "車", "神木", "休", "4秀", "2天",
]

# 用來儲存每個檔案的處理結果
records: list[tuple[str, str, str]] = []  # (folder, filename, status)

# 處理各資料夾內的 .gpx 檔
for folder in folders:
    dir_path = ROOT / folder
    if not dir_path.exists():
        print(f"資料夾不存在：{dir_path}")
        continue

    for gpx_file in dir_path.glob("*.gpx"):
        name = gpx_file.stem
        has_pos = any(kw in name for kw in pos_keywords)
        has_neg = any(kw in name for kw in neg_keywords)

        if not has_pos or has_neg:
            print(f"刪除：{gpx_file.name}")
            gpx_file.unlink()
            records.append((folder, gpx_file.name, "deleted"))
        else:
            print(f"保留：{gpx_file.name}")
            records.append((folder, gpx_file.name, "kept"))

# 分割 kept / deleted 清單
kept_records = [(f, fn) for f, fn, st in records if st == "kept"]
deleted_records = [(f, fn) for f, fn, st in records if st == "deleted"]

# 輸出兩個 CSV：kept 與 deleted
kept_csv = ROOT / "gpx_kept_list.csv"
deleted_csv = ROOT / "gpx_deleted_list.csv"

with open(kept_csv, "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.writer(f)
    writer.writerow(["folder", "filename"])
    writer.writerows(kept_records)

with open(deleted_csv, "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.writer(f)
    writer.writerow(["folder", "filename"])
    writer.writerows(deleted_records)

print(f"\n已將保留清單輸出到：{kept_csv}")
print(f"已將刪除清單輸出到：{deleted_csv}")

# 最後，將處理過的資料夾重新命名
for folder in folders:
    src = ROOT / folder
    dst = ROOT / f"Clean_{folder}"
    if src.exists():
        src.rename(dst)
        print(f"已將資料夾 '{folder}' 改名為 '{dst.name}'")
    else:
        print(f"找不到資料夾：{src}")
# Out:
# 刪除：01-06-2025 一日單攻桃山喀拉葉很滑很難走.gpx
# 刪除：0228_二訪武陵桃山@2019.gpx
# 刪除：0301_再訪桃山回程@2019.gpx
# 保留：0409桃山沒桃子.gpx
# 保留：0410桃山.gpx
# 保留：0521單攻桃山.gpx
# 保留：0829桃山.gpx
# 保留：1-18桃山.gpx
# 保留：10-15 桃山單攻.gpx
# 刪除：10-17桃山喀拉業一日單攻.gpx
# 保留：1091011-桃山.gpx
# 保留：1091226桃山單攻.gpx
# 保留：111.09.25桃山單攻.gpx
# 保留：111.8.22桃山單攻.gpx
# 保留：1110115桃山⛰️.gpx
# 刪除：1110116桃山瀑布步道.gpx
# 保留：112-9-24桃山單攻.gpx
# 刪除：112.09.24桃山+喀拉業單登.gpx
# 刪除：112.11.12 桃山瀑布.gpx
# 刪除：113.9.21桃山瀑布ok!.gpx
# 保留：12.03桃山.gpx
# 刪除：15-09-2024一日單攻武陵四秀少一秀.gpx
# 保留：20123-9-23爬桃山爬到厭世.gpx
# 保留：2014-5-25單攻桃山.gpx
# 刪除：20190204武陵農場桃山瀑布健行之旅.gpx
# 保留：20240303 與柯桃山初百岳.gpx
# 刪除：20240303桃山+喀拉業單攻.gpx
# 保留：20240303阿姿第一座百岳桃山.gpx
# 保留：20240421桃山.gpx
# 刪除：20240524桃山瀑布步道.gpx
# 刪除：20240610 桃山瀑布.gpx
# 保留：20240615桃山.gpx
# 保留：202408-10 桃山之行 硬啊.gpx
# 保留：20240917桃山.gpx
# 保留：20241012桃山單攻.gpx
# 保留：20241029桃山單攻.gpx
# 刪除：20241112桃山登頂未遂.gpx
# 刪除：2025-02-01 桃山瀑布.gpx
# 刪除：2025-04-04 凌晨輕裝登山 _ 武陵四秀-桃山.gpx
# 保留：2025-04-04 桃山.gpx
# 保留：2025-05-17 桃山單攻.gpx
# 刪除：2025-05-31 桃山單攻去程.gpx
# 刪除：2025-05-31 桃山單攻回程.gpx
# 刪除：2025-06-07 武陵二秀桃山，池有山.gpx
# 保留：2025-06-23 晨間輕裝登山 _ 2025-06-23 桃山單攻.gpx
# 刪除：2025-1-18 晨間輕裝登山_桃山瀑布步道.gpx
# 保留：2025-1-26 輕裝桃山.gpx
# 刪除：2025-1-4 武陵四秀桃山單攻.gpx
# 刪除：2025-2-1 晨間輕裝登山_桃山瀑布步道.gpx
# 刪除：2025-2-1 晨間輕裝登山_武陵二秀：桃山與池有山.gpx
# 刪除：2025-2-13 午後輕裝登山_桃山瀑布步道.gpx
# 刪除：2025-2-13 晨間輕裝登山_武陵二秀：桃山與池有山.gpx
# 刪除：2025-2-15 桃山、喀拉業單攻.gpx
# 刪除：2025-2-18桃山瀑布.gpx
# 保留：2025-2-21 晨間重裝登山_桃山步道.gpx
# 刪除：2025-3-23 桃山喀拉業單攻.gpx
# 刪除：2025-3-23 桃山碦拉業.gpx
# 刪除：2025-3-4 晨間輕裝登山_桃山瀑布步道 (1).gpx
# 刪除：2025-3-4 晨間輕裝登山_桃山瀑布步道.gpx
# 刪除：2025-3-7 午後輕裝登山_桃山瀑布步道.gpx
# 刪除：2025-3-8 桃山瀑布步道.gpx
# 刪除：2025-3-9 桃山單攻（休1.5小時）.gpx
# 保留：2025-4-12 晨間輕裝登山_桃山.gpx
# 刪除：2025-4-12 武陵四秀-單攻桃山.gpx
# 刪除：2025-4-19 晚間跑步_桃山瀑布步道.gpx
# 刪除：2025-4-19 桃山 喀拉業.gpx
# 刪除：2025-4-25 午後輕裝桃山瀑布.gpx
# 刪除：2025-4-26 中午跑步_桃山瀑布步道.gpx
# 刪除：2025-4-27 晚間輕裝登山_桃山瀑布步.gpx
# 刪除：2025-4-4 晚間輕裝登山_桃山瀑布步道.gpx
# 保留：2025-4-4 桃山一日單攻.gpx
# 刪除：2025-5-1 晨間輕裝登山_桃山瀑布步道.gpx
# 刪除：2025-5-14 武陵農場池有山-桃山一日單攻.gpx
# 刪除：2025-5-17 晨間輕裝登山_武陵二秀：桃山與池有山.gpx
# 保留：2025-5-17 桃山單攻.gpx
# 保留：2025-5-18  桃山單攻.gpx
# 保留：2025-5-18 桃山單攻.gpx
# 刪除：2025-5-18 武陵二秀：桃山與喀拉業山.gpx
# 保留：2025-5-20 登桃山一日遊.gpx
# 刪除：2025-5-22 晨間輕裝登山_桃山瀑布步道.gpx
# 刪除：2025-5-22 桃山瀑布步道.gpx
# 保留：2025-5-3 大鵰桃山單攻.gpx
# 保留：2025-5-30 端午節桃山單攻.gpx
# 刪除：2025-5-31 晨間輕裝登山_桃山瀑布步道.gpx
# 保留：2025-5-31端午節桃山單攻.gpx
# 刪除：2025-5-9 晚間輕裝登山_桃山瀑布步道.gpx
# 刪除：2025-6-1 晨間輕裝登山_新達山屋桃山瀑布步道.gpx
# 保留：2025-6-10 桃山單攻.gpx
# 刪除：2025-6-15 晨間輕裝登山_桃山瀑布步道.gpx
# 刪除：2025-6-15 桃喀ㄧ日單攻.gpx
# 保留：2025-6-15 桃山12刷.gpx
# 保留：2025-6-19 桃山單攻.gpx
# 刪除：2025-6-22 武陵二秀：桃山喀拉業.gpx
# 刪除：2025-6-23 晨間輕裝登山_桃山瀑布步道.gpx
# 保留：2025-6-23 桃山單攻.gpx
# 刪除：2025-6-29 單攻桃山加桃山瀑布.gpx
# 保留：2025-6-29 桃山.gpx
# 刪除：2025-6-7 武陵二秀，桃山池有山.gpx
# 刪除：2025-6-8 晚間輕裝登山_桃山瀑布步道.gpx
# 保留：2025-6-8 桃山11刷.gpx
# 刪除：2025-6-8 桃山喀拉業山單攻.gpx
# 刪除：2025-6-9 桃克單攻.gpx
# 刪除：2025-6-9 桃喀單攻.gpx
# 刪除：2025-7-11 桃山瀑布.gpx
# 刪除：2025-7-5 桃山步道、桃山瀑布.gpx
# 刪除：2025.05.18 桃山+喀拉業.gpx
# 刪除：20250425新達品田池有桃山.gpx
# 刪除：20250501 武陵四秀桃山-喀拉業.gpx
# 刪除：225.01.05武陵三秀 品田山、池有山、桃山.gpx
# 刪除：230311桃山喀拉業.gpx
# 刪除：231015 桃山瀑布+桃山登山步道1.2k.gpx
# 刪除：231111 桃山喀拉業.gpx
# 保留：240328桃山.gpx
# 刪除：292305桃山瀑布（未完）.gpx
# 刪除：3-19桃克單攻.gpx
# 保留：5-25-25 晨間輕裝登山 桃山瀑佈.gpx
# 保留：713桃山單攻.gpx
# 保留：8-11-2023單登桃山.gpx
# 保留：Amouter單攻桃山.gpx
# 刪除：Day2 桃山 喀拉業.gpx
# 保留：Jayden-桃山.gpx
# 刪除：T 日福德侍、麥樹仁南峰、麥樹仁、舊砲台山、加那桃山O型走.gpx
# 刪除：[武陵四秀] D2-新達山屋-桃山山屋.gpx
# 刪除：[武陵四秀] D3-桃山-武陵農場.gpx
# 保留：「桃山」單攻.gpx
# 刪除：一日三秀 (1).gpx
# 刪除：一日三秀-品田-池有-桃山 (1).gpx
# 刪除：一日三秀-品田-池有-桃山.gpx
# 刪除：一日三秀-池有、品田、桃山.gpx
# 刪除：一日三秀.gpx
# 刪除：一日二秀 桃山 喀拉業.gpx
# 刪除：一日二秀 桃山·喀拉葉山.gpx
# 刪除：一日二秀 桃山、喀拉業.gpx
# 刪除：一日二秀-桃山、喀拉業.gpx
# 刪除：一日二秀-桃山、喀拉業山.gpx
# 刪除：一日二秀（桃山喀拉業）.gpx
# 刪除：一日單攻 桃山 池有山.gpx
# 刪除：一日單攻桃山喀拉業.gpx
# 刪除：一日單攻武陵四秀.gpx
# 刪除：一日四秀 (1).gpx
# 刪除：一日四秀 (2).gpx
# 刪除：一日四秀 (3).gpx
# 刪除：一日四秀 (4).gpx
# 刪除：一日四秀......失敗.gpx
# 刪除：一日四秀.gpx
# 刪除：一日桃喀.gpx
# 保留：一日桃山 (1).gpx
# 保留：一日桃山 (2).gpx
# 保留：一日桃山.gpx
# 刪除：一日桃山、池有山.gpx
# 刪除：一日桃山上池有下.gpx
# 保留：一日桃山單攻.gpx
# 保留：一日桃山散步行.gpx
# 刪除：一日桃山（停車場出發）.gpx
# 刪除：一日桃詩🍑.gpx
# 刪除：一日武陵三秀 品田 池有 桃山.gpx
# 刪除：一日武陵二秀 桃山 池有.gpx
# 刪除：一日武陵二秀-桃山、喀拉業山、桃山瀑布.gpx
# 刪除：一日武陵二秀（桃山、喀拉業山） 2023-04-22.gpx
# 刪除：一日武陵四秀.gpx
# 刪除：初岳單攻-桃山.詩崙山.喀拉業山.gpx
# 保留：初百岳-桃山.gpx
# 保留：台中。和平。武陵桃山步道.gpx
# 保留：單攻桃山 (1).gpx
# 保留：單攻桃山 (2).gpx
# 刪除：單攻桃山 喀拉業.gpx
# 刪除：單攻桃山-喀拉業.gpx
# 保留：單攻桃山.gpx
# 刪除：單攻桃山喀拉業.gpx
# 刪除：單攻桃山喀拉業🍑.gpx
# 刪除：單攻桃山喀拉葉20220529.gpx
# 保留：單攻百岳No.48 桃山.gpx
# 保留：大霸尖山行前訓練-單攻桃山.gpx
# 刪除：天氣太好之桃山單攻加碼池有.gpx
# 保留：我的第一座百岳-桃山.gpx
# 刪除：新竹台中交界_一日二秀（池有山、桃山O型）.gpx
# 保留：新竹台中交界_桃山一日單登.gpx
# 刪除：新達品田山到桃山山屋.gpx
# 刪除：新達至桃山山屋.gpx
# 刪除：晨間桃山瀑布散策.gpx
# 保留：晨間輕裝登山 桃山.gpx
# 刪除：桃咯單攻.gpx
# 刪除：桃品池單攻.gpx
# 刪除：桃喀單攻 (1).gpx
# 刪除：桃喀單攻 (2).gpx
# 刪除：桃喀單攻 (3).gpx
# 刪除：桃喀單攻 (4).gpx
# 刪除：桃喀單攻 (5).gpx
# 刪除：桃喀單攻.gpx
# 保留：桃山 (1).gpx
# 保留：桃山 (10).gpx
# 保留：桃山 (11).gpx
# 保留：桃山 (12).gpx
# 保留：桃山 (13).gpx
# 保留：桃山 (14).gpx
# 保留：桃山 (15).gpx
# 保留：桃山 (16).gpx
# 保留：桃山 (17).gpx
# 保留：桃山 (18).gpx
# 保留：桃山 (19).gpx
# 保留：桃山 (2).gpx
# 保留：桃山 (20).gpx
# 保留：桃山 (21).gpx
# 保留：桃山 (22).gpx
# 保留：桃山 (23).gpx
# 保留：桃山 (24).gpx
# 保留：桃山 (25).gpx
# 保留：桃山 (26).gpx
# 保留：桃山 (27).gpx
# 保留：桃山 (28).gpx
# 保留：桃山 (29).gpx
# 保留：桃山 (3).gpx
# 保留：桃山 (30).gpx
# 保留：桃山 (31).gpx
# 保留：桃山 (32).gpx
# 保留：桃山 (33).gpx
# 保留：桃山 (34).gpx
# 保留：桃山 (35).gpx
# 保留：桃山 (36).gpx
# 保留：桃山 (37).gpx
# 保留：桃山 (38).gpx
# 保留：桃山 (39).gpx
# 保留：桃山 (4).gpx
# 保留：桃山 (40).gpx
# 保留：桃山 (41).gpx
# 保留：桃山 (42).gpx
# 保留：桃山 (43).gpx
# 保留：桃山 (44).gpx
# 保留：桃山 (45).gpx
# 保留：桃山 (46).gpx
# 保留：桃山 (47).gpx
# 保留：桃山 (48).gpx
# 保留：桃山 (49).gpx
# 保留：桃山 (5).gpx
# 保留：桃山 (50).gpx
# 保留：桃山 (51).gpx
# 保留：桃山 (52).gpx
# 保留：桃山 (53).gpx
# 保留：桃山 (54).gpx
# 保留：桃山 (55).gpx
# 保留：桃山 (56).gpx
# 保留：桃山 (57).gpx
# 保留：桃山 (58).gpx
# 保留：桃山 (59).gpx
# 保留：桃山 (6).gpx
# 保留：桃山 (60).gpx
# 保留：桃山 (61).gpx
# 保留：桃山 (7).gpx
# 保留：桃山 (8).gpx
# 保留：桃山 (9).gpx
# 保留：桃山 克啦業.gpx
# 刪除：桃山 克拉業 單攻.gpx
# 刪除：桃山 品田.gpx
# 刪除：桃山 喀拉業.gpx
# 刪除：桃山 喀拉葉山.gpx
# 刪除：桃山 池有.gpx
# 刪除：桃山 池有單攻.gpx
# 刪除：桃山 🏔池有山🏔單攻.gpx
# 刪除：桃山&喀拉業山.gpx
# 刪除：桃山&池有.gpx
# 刪除：桃山+喀拉業 2021-11-15(GPS軌跡有誤）.gpx
# 刪除：桃山+喀拉業.gpx
# 刪除：桃山-喀拉業.gpx
# 保留：桃山.gpx
# 保留：桃山1126.gpx
# 刪除：桃山15-喀拉業16.gpx
# 保留：桃山2.1K野餐20240316.gpx
# 保留：桃山20210411.gpx
# 保留：桃山2023-4-27.gpx
# 刪除：桃山O型走-1日.gpx
# 刪除：桃山_喀拉業.gpx
# 刪除：桃山·後段車上才關紀錄.gpx
# 刪除：桃山、喀拉業 (1).gpx
# 刪除：桃山、喀拉業.gpx
# 刪除：桃山、喀拉業單攻.gpx
# 刪除：桃山、喀拉業山單攻.gpx
# 刪除：桃山、喀拉業山單登.gpx
# 保留：桃山一日單攻 (1).gpx
# 保留：桃山一日單攻 (2).gpx
# 保留：桃山一日單攻.gpx
# 保留：桃山一日單攻_20220416.gpx
# 刪除：桃山上 池有下 O型 單攻.gpx
# 刪除：桃山上-池有山下.gpx
# 刪除：桃山上池有下（未上池有山三角點）.gpx
# 刪除：桃山下武陵.gpx
# 刪除：桃山下武陵山莊.gpx
# 保留：桃山不要再去了.gpx
# 刪除：桃山克拉業 (1).gpx
# 刪除：桃山克拉業.gpx
# 刪除：桃山克拉業單攻.gpx
# 刪除：桃山喀拉業 (1).gpx
# 刪除：桃山喀拉業 (2).gpx
# 刪除：桃山喀拉業 (3).gpx
# 刪除：桃山喀拉業 (4).gpx
# 刪除：桃山喀拉業 (5).gpx
# 刪除：桃山喀拉業 (6).gpx
# 刪除：桃山喀拉業 (7).gpx
# 刪除：桃山喀拉業 單攻.gpx
# 刪除：桃山喀拉業.gpx
# 刪除：桃山喀拉業D1.gpx
# 刪除：桃山喀拉業D2.gpx
# 刪除：桃山喀拉業一日單攻 (1).gpx
# 刪除：桃山喀拉業一日單攻.gpx
# 刪除：桃山喀拉業單攻 (1).gpx
# 刪除：桃山喀拉業單攻 (2).gpx
# 刪除：桃山喀拉業單攻 (3).gpx
# 刪除：桃山喀拉業單攻 (4).gpx
# 刪除：桃山喀拉業單攻 (5).gpx
# 刪除：桃山喀拉業單攻.gpx
# 刪除：桃山喀拉業單攻20240706.gpx
# 刪除：桃山喀拉業單攻，地震路徑崩塌.gpx
# 刪除：桃山喀拉業山 (1).gpx
# 刪除：桃山喀拉業山.gpx
# 刪除：桃山喀拉業山單攻.gpx
# 刪除：桃山喀拉葉.gpx
# 刪除：桃山喀拉葉單攻.gpx
# 刪除：桃山喀拉葉山.gpx
# 刪除：桃山喀拉葉山單攻.gpx
# 刪除：桃山喀拉頁 (1).gpx
# 刪除：桃山喀拉頁 (2).gpx
# 刪除：桃山喀拉頁.gpx
# 保留：桃山單.gpx
# 保留：桃山單攻 (1).gpx
# 保留：桃山單攻 (10).gpx
# 保留：桃山單攻 (11).gpx
# 保留：桃山單攻 (12).gpx
# 保留：桃山單攻 (13).gpx
# 保留：桃山單攻 (14).gpx
# 保留：桃山單攻 (15).gpx
# 保留：桃山單攻 (16).gpx
# 保留：桃山單攻 (17).gpx
# 保留：桃山單攻 (18).gpx
# 保留：桃山單攻 (19).gpx
# 保留：桃山單攻 (2).gpx
# 保留：桃山單攻 (20).gpx
# 保留：桃山單攻 (21).gpx
# 保留：桃山單攻 (22).gpx
# 保留：桃山單攻 (23).gpx
# 保留：桃山單攻 (24).gpx
# 保留：桃山單攻 (25).gpx
# 保留：桃山單攻 (26).gpx
# 保留：桃山單攻 (27).gpx
# 保留：桃山單攻 (28).gpx
# 保留：桃山單攻 (29).gpx
# 保留：桃山單攻 (3).gpx
# 保留：桃山單攻 (30).gpx
# 保留：桃山單攻 (31).gpx
# 保留：桃山單攻 (32).gpx
# 保留：桃山單攻 (33).gpx
# 保留：桃山單攻 (34).gpx
# 保留：桃山單攻 (35).gpx
# 保留：桃山單攻 (36).gpx
# 保留：桃山單攻 (37).gpx
# 保留：桃山單攻 (38).gpx
# 保留：桃山單攻 (39).gpx
# 保留：桃山單攻 (4).gpx
# 保留：桃山單攻 (40).gpx
# 保留：桃山單攻 (41).gpx
# 保留：桃山單攻 (42).gpx
# 保留：桃山單攻 (43).gpx
# 保留：桃山單攻 (44).gpx
# 保留：桃山單攻 (45).gpx
# 保留：桃山單攻 (46).gpx
# 保留：桃山單攻 (47).gpx
# 保留：桃山單攻 (48).gpx
# 保留：桃山單攻 (49).gpx
# 保留：桃山單攻 (5).gpx
# 保留：桃山單攻 (50).gpx
# 保留：桃山單攻 (51).gpx
# 保留：桃山單攻 (52).gpx
# 保留：桃山單攻 (6).gpx
# 保留：桃山單攻 (7).gpx
# 保留：桃山單攻 (8).gpx
# 保留：桃山單攻 (9).gpx
# 保留：桃山單攻.gpx
# 保留：桃山單攻2022-07-22.gpx
# 保留：桃山單攻20220730.gpx
# 保留：桃山單攻20240120.gpx
# 保留：桃山單攻20240714.gpx
# 保留：桃山單攻無傷完登.gpx
# 保留：桃山單日單攻.gpx
# 保留：桃山單登 (1).gpx
# 保留：桃山單登.gpx
# 保留：桃山完工.gpx
# 保留：桃山小辣椒.gpx
# 刪除：桃山山屋到武陵山莊.gpx
# 刪除：桃山山屋至喀拉業山.gpx
# 刪除：桃山撤退行XD.gpx
# 保留：桃山步道 (1).gpx
# 保留：桃山步道 (2).gpx
# 保留：桃山步道 (3).gpx
# 保留：桃山步道 (4).gpx
# 保留：桃山步道 (5).gpx
# 保留：桃山步道 (6).gpx
# 保留：桃山步道.gpx
# 刪除：桃山步道2.1K+桃山瀑布.gpx
# 刪除：桃山池有 (1).gpx
# 刪除：桃山池有.gpx
# 刪除：桃山池有0型縱走.gpx
# 刪除：桃山池有20221010.gpx
# 刪除：桃山池有O型.gpx
# 刪除：桃山池有單攻.gpx
# 刪除：桃山池有山一日來回.gpx
# 刪除：桃山池有山單攻.gpx
# 刪除：桃山瀑布 (1).gpx
# 刪除：桃山瀑布 (10).gpx
# 刪除：桃山瀑布 (11).gpx
# 刪除：桃山瀑布 (12).gpx
# 刪除：桃山瀑布 (13).gpx
# 刪除：桃山瀑布 (14).gpx
# 刪除：桃山瀑布 (15).gpx
# 刪除：桃山瀑布 (16).gpx
# 刪除：桃山瀑布 (17).gpx
# 刪除：桃山瀑布 (18).gpx
# 刪除：桃山瀑布 (19).gpx
# 刪除：桃山瀑布 (2).gpx
# 刪除：桃山瀑布 (20).gpx
# 刪除：桃山瀑布 (21).gpx
# 刪除：桃山瀑布 (22).gpx
# 刪除：桃山瀑布 (23).gpx
# 刪除：桃山瀑布 (24).gpx
# 刪除：桃山瀑布 (25).gpx
# 刪除：桃山瀑布 (26).gpx
# 刪除：桃山瀑布 (27).gpx
# 刪除：桃山瀑布 (28).gpx
# 刪除：桃山瀑布 (29).gpx
# 刪除：桃山瀑布 (3).gpx
# 刪除：桃山瀑布 (30).gpx
# 刪除：桃山瀑布 (31).gpx
# 刪除：桃山瀑布 (32).gpx
# 刪除：桃山瀑布 (33).gpx
# 刪除：桃山瀑布 (34).gpx
# 刪除：桃山瀑布 (35).gpx
# 刪除：桃山瀑布 (36).gpx
# 刪除：桃山瀑布 (4).gpx
# 刪除：桃山瀑布 (5).gpx
# 刪除：桃山瀑布 (6).gpx
# 刪除：桃山瀑布 (7).gpx
# 刪除：桃山瀑布 (8).gpx
# 刪除：桃山瀑布 (9).gpx
# 刪除：桃山瀑布+品田池有1.5K折返.gpx
# 刪除：桃山瀑布.gpx
# 刪除：桃山瀑布2023 9月10號.gpx
# 刪除：桃山瀑布健走.gpx
# 刪除：桃山瀑布步道 (1).gpx
# 刪除：桃山瀑布步道 (2).gpx
# 刪除：桃山瀑布步道 (3).gpx
# 刪除：桃山瀑布步道 (4).gpx
# 刪除：桃山瀑布步道 (5).gpx
# 刪除：桃山瀑布步道 (6).gpx
# 刪除：桃山瀑布步道 (7).gpx
# 刪除：桃山瀑布步道-12月午後.gpx
# 刪除：桃山瀑布步道.gpx
# 刪除：桃山瀑布步道2025-03-23.gpx
# 刪除：桃山瀑布步道2025-03-24.gpx
# 刪除：桃山瀑布步道健行.gpx
# 刪除：桃山瀑布輕裝行.gpx
# 刪除：桃山瀑布（lemon_7y1m,oliver_3y6m).gpx
# 保留：桃山登山 (1).gpx
# 保留：桃山登山.gpx
# 保留：桃山百岳.gpx
# 刪除：桃山碦拉業單攻.gpx
# 保留：桃山第八刷20240511.gpx
# 保留：桃山第十刷.gpx
# 刪除：桃山至武陵吊橋.gpx
# 刪除：桃山與喀拉業山單攻 2024.11.20.gpx
# 保留：桃山行.gpx
# 刪除：桃山詩崙碦拉業(單).gpx
# 保留：桃山軟爛行程.gpx
# 保留：桃山🍑一日單攻.gpx
# 刪除：桃山（武陵四秀）.gpx
# 保留：桃山，2023-11-4 晚間輕裝.gpx
# 保留：桃山，go.go.go.gpx
# 刪除：桃山，喀拉業山.gpx
# 刪除：桃山｜百岳048｜武陵四秀.gpx
# 保留：桃山￼.gpx
# 刪除：武陵4秀-桃山.gpx
# 保留：武陵一秀 - 桃山.gpx
# 刪除：武陵三秀 品田-池有-桃山 武2021-09-29 02_04 尚未命名的行程.gpx
# 刪除：武陵三秀單攻.gpx
# 刪除：武陵二秀-桃山、池有.gpx
# 刪除：武陵二秀“品田池有”單攻記錄.gpx
# 刪除：武陵二秀一日-桃山、喀拉業山、桃山瀑布.gpx
# 刪除：武陵二秀新達山屋前往桃山、喀拉業.gpx
# 刪除：武陵二秀（喀拉業和桃山）.gpx
# 刪除：武陵二秀（桃山、池有山）（單攻）.gpx
# 刪除：武陵二秀（桃山喀拉業）單攻.gpx
# 刪除：武陵二秀－桃山喀拉業山單攻1101115.gpx
# 刪除：武陵二秀～桃山&喀拉業山（單攻）.gpx
# 刪除：武陵四秀 (1).gpx
# 刪除：武陵四秀 (2).gpx
# 刪除：武陵四秀 - 桃山 單攻.gpx
# 刪除：武陵四秀 - 桃山.gpx
# 刪除：武陵四秀 D1 桃山, 百岳#48, 3325m.gpx
# 刪除：武陵四秀 一日單攻.gpx
# 刪除：武陵四秀 桃山 (1).gpx
# 刪除：武陵四秀 桃山.gpx
# 刪除：武陵四秀-桃山 (1).gpx
# 刪除：武陵四秀-桃山 (2).gpx
# 刪除：武陵四秀-桃山.gpx
# 刪除：武陵四秀-桃山單攻.gpx
# 刪除：武陵四秀.gpx
# 刪除：武陵四秀D1.gpx
# 刪除：武陵四秀D3.gpx
# 刪除：武陵四秀—桃山.gpx
# 刪除：武陵四秀一日單攻.gpx
# 刪除：武陵四秀一日單攻（逆走不停錶）.gpx
# 刪除：武陵四秀單攻.gpx
# 刪除：武陵四秀桃山+喀拉業山.gpx
# 刪除：武陵四秀桃山.gpx
# 刪除：武陵四秀～桃山、喀拉業.gpx
# 刪除：武陵四秀～桃山單攻.gpx
# 刪除：武陵山莊 - 桃山、喀拉業.gpx
# 保留：武陵桃山 (1).gpx
# 保留：武陵桃山.gpx
# 刪除：武陵桃山瀑布 (1).gpx
# 刪除：武陵桃山瀑布.gpx
# 刪除：武陵農場 桃山瀑布.gpx
# 刪除：武陵農場-桃山瀑布.gpx
# 刪除：武陵農場一桃山瀑布.gpx
# 保留：武陵農場桃山.gpx
# 刪除：武陵農場桃山瀑布步道.gpx
# 刪除：池有山.gpx
# 刪除：池有－桃山單攻.gpx
# 保留：百岳-桃山 (1).gpx
# 保留：百岳-桃山.gpx
# 刪除：睡過頭的桃山喀拉頁山單攻.gpx
# 保留：石猴桃山沼平.gpx
# 刪除：第三次桃山賞白牆.gpx
# 刪除：第二座百岳：桃山.gpx
# 保留：聖誕桃山.gpx
# 刪除：雪山坑步道.gpx
# 刪除：雪山群峰-桃山喀拉業一日行.gpx
# 刪除：［百岳］一日武陵三秀（桃山、喀拉業山、池有山）.gpx
# 刪除：［百岳］武陵四秀- 桃山喀拉業.gpx
# 保留：0521桃山單攻.gpx
# 保留：1100514桃山.gpx
# 保留：1110925桃山.gpx
# 刪除：1120504 一日武陵四秀(桃山、喀拉業山、池有山、品田山).gpx
# 保留：1120521桃山單登.gpx
# 保留：1130920單攻桃山.gpx
# 刪除：11_27武陵四秀-桃山.gpx
# 保留：13825桃山單攻.gpx
# 保留：2017-04-30 桃山單攻.gpx
# 刪除：2017.12.23-24 武陵二秀之桃山喀拉業(親子登山_小三至小六).gpx
# 刪除：20181229_一日三秀-品田 池有 桃山.gpx
# 刪除：20190615桃山喀拉業單攻.gpx
# 刪除：20190629_一日桃山喀拉業.gpx
# 刪除：20190629桃山喀拉業單攻.gpx
# 保留：20190914桃山單攻.gpx
# 刪除：20191227 池有山.桃山O型線單攻.gpx
# 刪除：2020-03-01桃山喀拉葉.gpx
# 刪除：20200418-19桃山-詩崙山-喀拉業山(兩天一夜).gpx
# 保留：20200716 - 一日單攻桃山.gpx
# 保留：20201031桃山.gpx
# 刪除：20201219 武陵三秀品田池有桃山.gpx
# 保留：2020322桃山單攻.gpx
# 刪除：2020_07_12武陵二秀-池有桃山.gpx
# 刪除：2021 武陵二秀：桃山、池有山O型單攻.gpx
# 保留：2021-03-13_桃山一日單攻.gpx
# 刪除：2021-12-25 桃山 +桃山瀑布.gpx
# 保留：2021.04.17桃山單攻.gpx
# 刪除：2021.12.13 雪山聖稜線O型 ( O聖 ).gpx
# 刪除：20210228_20210301_台中和平武陵三秀.gpx
# 保留：20210321 桃山.gpx
# 刪除：20210321二刷桃山慢慢走.gpx
# 刪除：20210419 桃山池有單攻.gpx
# 保留：20210814桃山單攻.gpx
# 刪除：20210927-28武陵四秀2日.gpx
# 保留：20211205桃山.gpx
# 保留：20211210桃山單攻.gpx
# 刪除：2021_04_30 - 05_01 武陵四秀.gpx
# 保留：2021桃山.gpx
# 保留：2022.12.24 桃山.gpx
# 保留：20220404桃山單攻.gpx
# 保留：20220414桃山單攻.gpx
# 保留：20220704 桃山單攻.gpx
# 刪除：20220723_武陵二秀-桃喀單攻.gpx
# 保留：20220806 桃山.gpx
# 刪除：20221002桃山_詩崙山_喀拉業山.gpx
# 刪除：20221121 桃山 (武陵四秀).gpx
# 保留：20221121桃山單攻.gpx
# 保留：20221211 桃山單攻.gpx
# 刪除：2023-03-27…29_武陵四秀逆走（3天2夜).gpx
# 保留：2023-04-22_附中桃山單攻.gpx
# 刪除：20230430 阿湯哥桃山喀拉業單攻.gpx
# 刪除：20230714武陵四秀（桃山）.gpx
# 保留：20231014 - 15 米羅佐得寒上桃山(米佐桃縱走).gpx
# 保留：20231026桃山.gpx
# 刪除：2023_10_23～25 武陵四秀.gpx
# 保留：2024.12.07單攻桃山初體驗.gpx
# 刪除：20240813 武陵四秀D1 武陵山莊-桃山-桃山山屋 (缺2K-桃山山屋路徑).gpx
# 保留：20240902 桃山單攻.gpx
# 刪除：2025-02-28_桃山神木D1(武陵山莊-桃山-H2880營地).gpx
# 刪除：2025-03-01_桃山神木D2(H2880營地-桃山神木).gpx
# 刪除：2025-03-02_桃山神木D3(H2880營地-武陵山莊).gpx
# 保留：20250517-桃山.gpx
# 保留：20251221桃山單攻嗚嗚嗚.gpx
# 保留：228桃山單攻GO.gpx
# 刪除：230914桃喀單攻.gpx
# 保留：240517桃山單攻.gpx
# 保留：BENTANG桃山單攻.gpx
# 刪除：D1 武陵山莊_桃山_桃山山屋.gpx
# 刪除：Ko.gpx
# 刪除：Ryan＆Angel_桃喀單攻首刷.gpx
# 刪除：_山.gpx
# 刪除：ℂ𝕙𝕖𝕣雪兒 桃喀單攻（桃山、喀拉業）.gpx
# 刪除：【武陵二秀】桃山、喀拉業山單攻.gpx
# 刪除：一天一喀桃.gpx
# 刪除：一日三秀.gpx
# 刪除：一日桃喀 (1).gpx
# 刪除：一日桃喀 (2).gpx
# 刪除：一日桃喀 桃山 喀拉業.gpx
# 刪除：一日桃喀.gpx
# 保留：一日桃山 (1).gpx
# 保留：一日桃山.gpx
# 保留：一日桃山單攻.gpx
# 刪除：一日武陵三秀(桃喀池).gpx
# 刪除：一日武陵四秀 (1).gpx
# 刪除：一日武陵四秀.gpx
# 保留：佐得寒喀桃山武陵.gpx
# 保留：包愛罐帶小孩桃山單攻.gpx
# 刪除：取桃計畫.gpx
# 刪除：台中－臺灣百大必訪步道武陵四秀登山步道20241222173230.gpx
# 刪除：品田山-池有山-桃山一日單攻.gpx
# 刪除：喀拉業.gpx
# 保留：單攻桃山 (1).gpx
# 保留：單攻桃山.gpx
# 刪除：單攻桃山喀拉業山。Vito.20220604.gpx
# 保留：單攻桃山（上）.gpx
# 刪除：單日喀拉業 桃山.gpx
# 刪除：四秀桃山.gpx
# 刪除：妮妮.gpx
# 保留：小魚桃山生日趴.gpx
# 保留：慢速單攻桃山.gpx
# 刪除：日本桃山瞭望台原路折返.gpx
# 刪除：桃克.gpx
# 刪除：桃喀.gpx
# 保留：桃山 (1).gpx
# 保留：桃山 (10).gpx
# 保留：桃山 (11).gpx
# 保留：桃山 (12).gpx
# 保留：桃山 (13).gpx
# 保留：桃山 (14).gpx
# 保留：桃山 (15).gpx
# 保留：桃山 (16).gpx
# 保留：桃山 (17).gpx
# 保留：桃山 (18).gpx
# 保留：桃山 (19).gpx
# 保留：桃山 (2).gpx
# 保留：桃山 (20).gpx
# 保留：桃山 (21).gpx
# 保留：桃山 (22).gpx
# 保留：桃山 (23).gpx
# 保留：桃山 (24).gpx
# 保留：桃山 (25).gpx
# 保留：桃山 (26).gpx
# 保留：桃山 (27).gpx
# 保留：桃山 (28).gpx
# 保留：桃山 (29).gpx
# 保留：桃山 (3).gpx
# 保留：桃山 (30).gpx
# 保留：桃山 (31).gpx
# 保留：桃山 (32).gpx
# 保留：桃山 (33).gpx
# 保留：桃山 (34).gpx
# 保留：桃山 (35).gpx
# 保留：桃山 (36).gpx
# 保留：桃山 (37).gpx
# 保留：桃山 (38).gpx
# 保留：桃山 (39).gpx
# 保留：桃山 (4).gpx
# 保留：桃山 (40).gpx
# 保留：桃山 (41).gpx
# 保留：桃山 (42).gpx
# 保留：桃山 (43).gpx
# 保留：桃山 (44).gpx
# 保留：桃山 (45).gpx
# 保留：桃山 (46).gpx
# 保留：桃山 (47).gpx
# 保留：桃山 (48).gpx
# 保留：桃山 (49).gpx
# 保留：桃山 (5).gpx
# 保留：桃山 (6).gpx
# 保留：桃山 (7).gpx
# 保留：桃山 (8).gpx
# 保留：桃山 (9).gpx
# 刪除：桃山 池有一日單攻.gpx
# 保留：桃山(上).gpx
# 刪除：桃山(下山).gpx
# 刪除：桃山-喀拉業山.gpx
# 刪除：桃山-未完成.gpx
# 保留：桃山.gpx
# 保留：桃山1.5K.gpx
# 保留：桃山1111008 (1).gpx
# 保留：桃山1111008.gpx
# 保留：桃山1125.gpx
# 保留：桃山1日單攻.gpx
# 保留：桃山D1.gpx
# 刪除：桃山_喀拉業山 (兩天一夜).gpx
# 刪除：桃山、喀拉業山.gpx
# 保留：桃山一日單攻 (1).gpx
# 保留：桃山一日單攻 (2).gpx
# 保留：桃山一日單攻 (3).gpx
# 保留：桃山一日單攻 (4).gpx
# 保留：桃山一日單攻 (5).gpx
# 保留：桃山一日單攻 (6).gpx
# 保留：桃山一日單攻 (7).gpx
# 保留：桃山一日單攻 (8).gpx
# 保留：桃山一日單攻 (9).gpx
# 保留：桃山一日單攻.gpx
# 保留：桃山一日單攻！.gpx
# 刪除：桃山三刷.gpx
# 刪除：桃山三角點-桃山山屋.gpx
# 保留：桃山上吃粽子.gpx
# 保留：桃山上山.gpx
# 刪除：桃山上池有下.gpx
# 刪除：桃山下山.gpx
# 刪除：桃山下桃山登山口.gpx
# 保留：桃山出大景.gpx
# 刪除：桃山加池有山單攻.gpx
# 刪除：桃山喀拉業.gpx
# 刪除：桃山喀拉業2日行D1.gpx
# 刪除：桃山喀拉業2日行D2.gpx
# 刪除：桃山喀拉業單攻 (1).gpx
# 刪除：桃山喀拉業單攻.gpx
# 刪除：桃山喀拉業山.gpx
# 刪除：桃山喀拉業山兩天一夜.gpx
# 刪除：桃山喀拉業山（一日）.gpx
# 保留：桃山單供20230625.gpx
# 保留：桃山單攻 (1).gpx
# 保留：桃山單攻 (10).gpx
# 保留：桃山單攻 (11).gpx
# 保留：桃山單攻 (12).gpx
# 保留：桃山單攻 (13).gpx
# 保留：桃山單攻 (14).gpx
# 保留：桃山單攻 (15).gpx
# 保留：桃山單攻 (16).gpx
# 保留：桃山單攻 (17).gpx
# 保留：桃山單攻 (18).gpx
# 保留：桃山單攻 (19).gpx
# 保留：桃山單攻 (2).gpx
# 保留：桃山單攻 (20).gpx
# 保留：桃山單攻 (21).gpx
# 保留：桃山單攻 (22).gpx
# 保留：桃山單攻 (23).gpx
# 保留：桃山單攻 (24).gpx
# 保留：桃山單攻 (25).gpx
# 保留：桃山單攻 (26).gpx
# 保留：桃山單攻 (27).gpx
# 保留：桃山單攻 (28).gpx
# 保留：桃山單攻 (29).gpx
# 保留：桃山單攻 (3).gpx
# 保留：桃山單攻 (30).gpx
# 保留：桃山單攻 (31).gpx
# 保留：桃山單攻 (32).gpx
# 保留：桃山單攻 (33).gpx
# 保留：桃山單攻 (34).gpx
# 保留：桃山單攻 (35).gpx
# 保留：桃山單攻 (36).gpx
# 保留：桃山單攻 (37).gpx
# 保留：桃山單攻 (38).gpx
# 保留：桃山單攻 (39).gpx
# 保留：桃山單攻 (4).gpx
# 保留：桃山單攻 (40).gpx
# 保留：桃山單攻 (41).gpx
# 保留：桃山單攻 (42).gpx
# 保留：桃山單攻 (43).gpx
# 保留：桃山單攻 (44).gpx
# 保留：桃山單攻 (45).gpx
# 保留：桃山單攻 (46).gpx
# 保留：桃山單攻 (47).gpx
# 保留：桃山單攻 (48).gpx
# 保留：桃山單攻 (49).gpx
# 保留：桃山單攻 (5).gpx
# 保留：桃山單攻 (50).gpx
# 保留：桃山單攻 (6).gpx
# 保留：桃山單攻 (7).gpx
# 保留：桃山單攻 (8).gpx
# 保留：桃山單攻 (9).gpx
# 刪除：桃山單攻 (單程，下一半手錶沒電，縮減檔案).gpx
# 保留：桃山單攻 全程.gpx
# 刪除：桃山單攻 去程.gpx
# 刪除：桃山單攻 吊橋起登.gpx
# 刪除：桃山單攻 回程.gpx
# 保留：桃山單攻(原路去回).gpx
# 刪除：桃山單攻+桃山瀑布.gpx
# 刪除：桃山單攻-未完.gpx
# 保留：桃山單攻.gpx
# 保留：桃山單攻1101104.gpx
# 保留：桃山單攻20201025.gpx
# 保留：桃山單攻20210814.gpx
# 保留：桃山單攻20241208.gpx
# 保留：桃山單攻230610.gpx
# 保留：桃山單攻一日遊.gpx
# 保留：桃山單攻武陵山莊出發.gpx
# 保留：桃山單登.gpx
# 刪除：桃山四秀.gpx
# 刪除：桃山回程.gpx
# 刪除：桃山山屋尿尿.gpx
# 保留：桃山往返.gpx
# 保留：桃山快樂腳.gpx
# 保留：桃山慢速單攻.gpx
# 保留：桃山步道 (1).gpx
# 保留：桃山步道 (2).gpx
# 保留：桃山步道.gpx
# 刪除：桃山池有 (1).gpx
# 刪除：桃山池有 (2).gpx
# 刪除：桃山池有 (3).gpx
# 刪除：桃山池有.gpx
# 刪除：桃山池有O型.gpx
# 刪除：桃山池有o型縱走.gpx
# 刪除：桃山池有一日.gpx
# 刪除：桃山池有一日攻略.gpx
# 刪除：桃山池有山.gpx
# 刪除：桃山池有山縱走.gpx
# 刪除：桃山環走池有山.gpx
# 刪除：桃山登山山徑上武陵二秀202010101643.gpx.gpx
# 刪除：桃山神木-喀拉業北稜-扁柏神殿.gpx
# 刪除：桃山神木經杜鵑稜線上鐵杉林營地.gpx
# 刪除：桃山神木鐵杉林營地到桃山登山口.gpx
# 刪除：桃山耍廢兩天一夜.gpx
# 保留：桃山肉腳單.gpx
# 保留：桃山處女團.gpx
# 保留：桃山陡上之旅.gpx
# 保留：桃山雪季單攻.gpx
# 刪除：桃山（2天1夜）.gpx
# 保留：桃山（單攻）.gpx
# 刪除：桃山＋池有山.gpx
# 刪除：桃山，池有單攻.gpx
# 刪除：武陵3秀.gpx
# 刪除：武陵三秀 (1).gpx
# 刪除：武陵三秀(桃山→池有山→品田山).gpx
# 刪除：武陵三秀.gpx
# 刪除：武陵三秀2日桃山上.gpx
# 刪除：武陵三秀O型-品田池有桃山.gpx
# 刪除：武陵三秀一日遊.gpx
# 刪除：武陵二秀 D1 [武陵山莊-桃山-桃山山屋] (by Simon's Garmin Fenix 7X, 2022.08.08).gpx
# 刪除：武陵二秀(桃山+池有山O型).gpx
# 刪除：武陵二秀(池有、桃山) (1).gpx
# 刪除：武陵二秀(池有、桃山).gpx
# 刪除：武陵二秀(池有桃山).gpx
# 刪除：武陵二秀桃山池有單攻.gpx
# 刪除：武陵二秀桃山池有山.gpx
# 刪除：武陵二秀－桃山喀拉業山單攻1101115.gpx
# 刪除：武陵四秀 (1).gpx
# 刪除：武陵四秀 (2).gpx
# 刪除：武陵四秀 桃山單攻.gpx
# 刪除：武陵四秀 池有 品田 桃山 (缺喀拉業).gpx
# 刪除：武陵四秀-桃山&池有山.gpx
# 刪除：武陵四秀-桃山.gpx
# 刪除：武陵四秀-桃山單攻.gpx
# 刪除：武陵四秀.gpx
# 刪除：武陵四秀.桃山池有大O.20180722.gpx
# 刪除：武陵四秀之3-桃山、喀拉業、池有山.gpx
# 刪除：武陵四秀桃山.gpx
# 刪除：武陵四秀登山步道202307081542.gpx
# 保留：武陵山莊+桃山登山山徑來回.gpx
# 刪除：武陵山莊-桃山-桃山山屋-喀拉業山.gpx
# 刪除：武陵山莊上桃山喀拉業山走訪扁柏神殿出米羅.gpx
# 保留：武陵桃山 (1).gpx
# 保留：武陵桃山 (2).gpx
# 保留：武陵桃山.gpx
# 刪除：武陵農場-桃山-桃山山屋-武陵農場2018.10.22-10.24.gpx
# 刪除：武陵農場-桃山山屋.gpx
# 刪除：池有山桃山_池桃O型縱走_武陵四秀.gpx
# 保留：浪花桃山.gpx
# 刪除：第二顆百岳🙌🏻GET.gpx
# 保留：米羅神殿上桃山.gpx
# 刪除：這才是平民.gpx
# 刪除：遠山含笑 芳草碧連天.gpx
# 刪除：重裝 新達到桃山下武陵山莊.gpx
# 保留：馬偕寶寶桃山單攻.gpx
#
# 已將保留清單輸出到：d:\_iSpan\期末專題\analyze_gpx\FileClean\gpx_kept_list.csv
# 已將刪除清單輸出到：d:\_iSpan\期末專題\analyze_gpx\FileClean\gpx_deleted_list.csv
# 已將資料夾 'HikingBook_gpx' 改名為 'Clean_HikingBook_gpx'
# 已將資料夾 'HikingNote_gpx' 改名為 'Clean_HikingNote_gpx'
