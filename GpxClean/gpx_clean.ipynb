# %%
# python -m pip install gpxpy
# Out:
# 'pip' ���O�����Υ~���R�O�B�i���檺�{���Χ妸�ɡC

# %%
import gpxpy
import pandas as pd
from pathlib import Path

# 1. Notebook 目前所在資料夾 (…\analyze_gpx\GpxClean)
NOTEBOOK_DIR = Path.cwd()

# 2. 專案根目錄 (…\analyze_gpx)
PROJECT_ROOT = NOTEBOOK_DIR.parent

# 3. 原始 GPX 放在 FileClean 裡
FILECLEAN_DIR = PROJECT_ROOT / 'FileClean'

# 4. 定義要處理的資料夾與對應前綴
input_dirs = {
    'Clean_HikingBook_gpx': 'HB',
    'Clean_HikingNote_gpx': 'HN'
}

# 5. 輸出目錄：…\analyze_gpx\GpxClean\gpx_to_csv
output_dir = NOTEBOOK_DIR / 'gpx_to_csv'
output_dir.mkdir(exist_ok=True, parents=True)

# 紀錄若沒 time 欄的檔案
missing_time_files = []

for folder_name, prefix in input_dirs.items():
    folder_path = FILECLEAN_DIR / folder_name
    if not folder_path.exists():
        print(f"資料夾不存在，跳過：{folder_path}")
        continue

    for gpx_path in folder_path.glob('*.gpx'):
        # 解析 GPX
        with open(gpx_path, 'r', encoding='utf-8') as f:
            gpx = gpxpy.parse(f)

        # 收集所有 track point
        points = []
        for track in gpx.tracks:
            for segment in track.segments:
                for point in segment.points:
                    points.append({
                        'lat': point.latitude,
                        'lon': point.longitude,
                        'ele': point.elevation,
                        'time': point.time
                    })

        # 轉成 DataFrame
        df = pd.DataFrame(points)

        # ——【功能1】轉 time 欄為 datetime，若真的沒欄位就記錄檔名
        if 'time' not in df.columns:
            missing_time_files.append(gpx_path.name)
        else:
            df['time'] = pd.to_datetime(df['time'])

        # 組出輸出檔名：前綴 + 原檔名（不含副檔名） + .csv
        out_name = f"{prefix}{gpx_path.stem}.csv"
        out_path = output_dir / out_name

        # ——【功能2】如果檔案已存在就跳過
        if out_path.exists():
            print(f"已存在，跳過：{out_name}")
        else:
            df.to_csv(out_path, index=False, encoding='utf-8-sig')
            rel = out_path.relative_to(PROJECT_ROOT)
            print(f"已儲存：{rel}")

# 如果有任何缺少 time 欄的檔案，一次列出
if missing_time_files:
    print("\nWARNING: 以下檔案沒有 `time` 欄位，已跳過轉換：")
    for fname in missing_time_files:
        print(f" - {fname}")

# 最後再印出統計
csv_files = list(output_dir.glob('*.csv'))
print(f"\ngpx_to_csv 資料夾中共有 {len(csv_files)} 筆資料（CSV 檔）")
# Out:
# 已儲存：GpxClean\gpx_to_csv\HB0409桃山沒桃子.csv
# 已儲存：GpxClean\gpx_to_csv\HB0410桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB0521單攻桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB0829桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB1-18桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB10-15 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB1091011-桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB1091226桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB111.09.25桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB111.8.22桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB1110115桃山⛰️.csv
# 已儲存：GpxClean\gpx_to_csv\HB112-9-24桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB12.03桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB20123-9-23爬桃山爬到厭世.csv
# 已儲存：GpxClean\gpx_to_csv\HB2014-5-25單攻桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB20200418 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB202011 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB20201212 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2021-11-25 武陵桃山上行.csv
# 已儲存：GpxClean\gpx_to_csv\HB2021-11-28 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2021-11-7 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2021-12-11 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2021-12-20 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2021-9-26 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB20210320_桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB20210927桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB20211016-桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2022-10-08 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2022-6-19 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2022-6-25 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2022-6-3 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2022-8-28 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2022-9-10 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB20220703_桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB20220710 一日桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB20220910中秋自虐桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2022100 重裝16kg上桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB20221001桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2022桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-05-05 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-054桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-0617 桃山一日單攻成功.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-09-16桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-09-23 一日桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-10-15桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-10-2 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-10-27 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-10-28 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-10-9 桃山一日遊.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-11-25 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-11-26 桃山單攻 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-11-26 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-11-4 桃山一日單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-12-31 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-3-23 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-4-3 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-4-30 第一座百岳 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-5-27 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-6-10 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-6-23 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-6-8 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-7-11 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-7-11桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-7-23 桃山單攻 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-7-23 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-7-5 桃山武陵.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-8-12 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-8-13 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-8-13 重裝桃山訓.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-8-19 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-8-26 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-8-27 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023-9-24 桃山單攻練腿.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023.12.27桃山一日單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2023.9.17桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB20230610桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB20230711 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB20231108桃山輕鬆自在行.csv
# 已儲存：GpxClean\gpx_to_csv\HB20231213-桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-02-02 武陵第一秀。桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-0608桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-1-29 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-10-13桃山單攻看日出.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-10-22 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-10-6 桃山步道.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-11-09 單攻桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-11-23桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-11-24 ㄧ日桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-11-24 小桃山猴子偷桃.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-11-24 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-11-25 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-11-9 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-12-1 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-12-14 輕裝登山_桃山步道.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-12-15 晚間輕裝登山_桃山步道.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-12-22 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-12-22 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-12-22 桃山步道.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-12-22_桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-12-23 晨間輕裝登山_桃山步道.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-12-28 晚間輕裝登山_桃山步道.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-12-3 武陵農場桃山步道.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-12-31桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-12-6 晨間輕裝上桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-12-7 單攻桃山、池友山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-12-7 晨間輕裝登山_桃山步道.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-12-8 晚間輕裝登山_桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-12-8 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-2-23 桃山單攻去.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-3-15 晨間重裝桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-3-21桃山步道.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-3-30 登桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-5-19桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-5-5 桃山一日.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-6-16 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-6-17 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-7-1 桃山單攻🍑.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-7-19 桃山步道.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-7-7  武陵桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-8-10 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-8-11 晨間輕裝登山_桃山步道.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-8-24 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-9-1 晨間輕裝登山_桃山步道.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-9-1 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-9-1 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024-9-18 午後輕裝登山_桃山步道.csv
# 已儲存：GpxClean\gpx_to_csv\HB2024.12.16  桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB20240214桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB20240303 與柯桃山初百岳.csv
# 已儲存：GpxClean\gpx_to_csv\HB20240303阿姿第一座百岳桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB20240421桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB20240615桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB202408-10 桃山之行 硬啊.csv
# 已儲存：GpxClean\gpx_to_csv\HB20240917桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB20241012桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB20241029桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-04-04 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-05-17 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-06-23 晨間輕裝登山 _ 2025-06-23 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-1-26 輕裝桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-2-21 晨間重裝登山_桃山步道.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-4-12 晨間輕裝登山_桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-4-4 桃山一日單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-5-17 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-5-18  桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-5-18 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-5-20 登桃山一日遊.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-5-3 大鵰桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-5-30 端午節桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-5-31端午節桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-6-10 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-6-15 桃山12刷.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-6-19 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-6-23 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-6-29 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB2025-6-8 桃山11刷.csv
# 已儲存：GpxClean\gpx_to_csv\HB240328桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB5-25-25 晨間輕裝登山 桃山瀑佈.csv
# 已儲存：GpxClean\gpx_to_csv\HB713桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB8-11-2023單登桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HBAmouter單攻桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HBJayden-桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB「桃山」單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB一日桃山 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HB一日桃山 (2).csv
# 已儲存：GpxClean\gpx_to_csv\HB一日桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB一日桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB一日桃山散步行.csv
# 已儲存：GpxClean\gpx_to_csv\HB初百岳-桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB台中。和平。武陵桃山步道.csv
# 已儲存：GpxClean\gpx_to_csv\HB單攻桃山 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HB單攻桃山 (2).csv
# 已儲存：GpxClean\gpx_to_csv\HB單攻桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB單攻百岳No.48 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB大霸尖山行前訓練-單攻桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB我的第一座百岳-桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB新竹台中交界_桃山一日單登.csv
# 已儲存：GpxClean\gpx_to_csv\HB晨間輕裝登山 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (10).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (11).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (12).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (13).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (14).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (15).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (16).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (17).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (18).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (19).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (2).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (20).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (21).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (22).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (23).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (24).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (25).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (26).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (27).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (28).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (29).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (3).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (30).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (31).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (32).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (33).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (34).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (35).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (36).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (37).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (38).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (39).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (4).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (40).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (41).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (42).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (43).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (44).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (45).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (46).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (47).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (48).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (49).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (5).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (50).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (51).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (52).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (53).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (54).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (55).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (56).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (57).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (58).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (59).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (6).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (60).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (61).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (7).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (8).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 (9).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山 克啦業.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山1126.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山2.1K野餐20240316.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山20210411.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山2023-4-27.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山一日單攻 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山一日單攻 (2).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山一日單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山一日單攻_20220416.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山不要再去了.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (10).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (11).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (12).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (13).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (14).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (15).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (16).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (17).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (18).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (19).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (2).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (20).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (21).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (22).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (23).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (24).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (25).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (26).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (27).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (28).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (29).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (3).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (30).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (31).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (32).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (33).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (34).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (35).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (36).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (37).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (38).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (39).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (4).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (40).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (41).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (42).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (43).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (44).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (45).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (46).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (47).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (48).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (49).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (5).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (50).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (51).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (52).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (6).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (7).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (8).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻 (9).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻2022-07-22.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻20220730.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻20240120.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻20240714.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單攻無傷完登.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單日單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單登 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山單登.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山完工.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山小辣椒.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山步道 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山步道 (2).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山步道 (3).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山步道 (4).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山步道 (5).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山步道 (6).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山步道.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山登山 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山登山.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山百岳.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山第八刷20240511.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山第十刷.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山行.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山軟爛行程.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山🍑一日單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山，2023-11-4 晚間輕裝.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山，go.go.go.csv
# 已儲存：GpxClean\gpx_to_csv\HB桃山￼.csv
# 已儲存：GpxClean\gpx_to_csv\HB武陵一秀 - 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB武陵桃山 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HB武陵桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB武陵農場桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB百岳-桃山 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HB百岳-桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HB石猴桃山沼平.csv
# 已儲存：GpxClean\gpx_to_csv\HB聖誕桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN0521桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN1100514桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN1110925桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN1120521桃山單登.csv
# 已儲存：GpxClean\gpx_to_csv\HN1130920單攻桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN13825桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN2017-04-30 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN20190914桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN20200716 - 一日單攻桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN20201031桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN2020322桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN2021-03-13_桃山一日單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN2021.04.17桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN20210321 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN20210814桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN20211205桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN20211210桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN2021桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN2022.12.24 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN20220404桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN20220414桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN20220704 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN20220806 桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN20221121桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN20221211 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN2023-04-22_附中桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN20231014 - 15 米羅佐得寒上桃山(米佐桃縱走).csv
# 已儲存：GpxClean\gpx_to_csv\HN20231026桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN2024.12.07單攻桃山初體驗.csv
# 已儲存：GpxClean\gpx_to_csv\HN20240902 桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN20250517-桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN20251221桃山單攻嗚嗚嗚.csv
# 已儲存：GpxClean\gpx_to_csv\HN228桃山單攻GO.csv
# 已儲存：GpxClean\gpx_to_csv\HN240517桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HNBENTANG桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN一日桃山 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HN一日桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN一日桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN佐得寒喀桃山武陵.csv
# 已儲存：GpxClean\gpx_to_csv\HN包愛罐帶小孩桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN單攻桃山 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HN單攻桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN單攻桃山（上）.csv
# 已儲存：GpxClean\gpx_to_csv\HN小魚桃山生日趴.csv
# 已儲存：GpxClean\gpx_to_csv\HN慢速單攻桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (10).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (11).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (12).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (13).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (14).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (15).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (16).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (17).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (18).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (19).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (2).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (20).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (21).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (22).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (23).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (24).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (25).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (26).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (27).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (28).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (29).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (3).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (30).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (31).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (32).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (33).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (34).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (35).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (36).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (37).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (38).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (39).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (4).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (40).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (41).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (42).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (43).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (44).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (45).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (46).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (47).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (48).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (49).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (5).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (6).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (7).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (8).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山 (9).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山(上).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山1.5K.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山1111008 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山1111008.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山1125.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山1日單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山D1.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山一日單攻 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山一日單攻 (2).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山一日單攻 (3).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山一日單攻 (4).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山一日單攻 (5).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山一日單攻 (6).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山一日單攻 (7).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山一日單攻 (8).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山一日單攻 (9).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山一日單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山一日單攻！.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山上吃粽子.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山上山.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山出大景.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單供20230625.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (10).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (11).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (12).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (13).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (14).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (15).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (16).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (17).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (18).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (19).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (2).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (20).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (21).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (22).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (23).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (24).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (25).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (26).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (27).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (28).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (29).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (3).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (30).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (31).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (32).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (33).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (34).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (35).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (36).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (37).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (38).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (39).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (4).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (40).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (41).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (42).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (43).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (44).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (45).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (46).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (47).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (48).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (49).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (5).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (50).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (6).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (7).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (8).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 (9).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻 全程.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻(原路去回).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻1101104.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻20201025.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻20210814.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻20241208.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻230610.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻一日遊.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單攻武陵山莊出發.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山單登.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山往返.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山快樂腳.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山慢速單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山步道 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山步道 (2).csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山步道.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山肉腳單.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山處女團.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山陡上之旅.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山雪季單攻.csv
# 已儲存：GpxClean\gpx_to_csv\HN桃山（單攻）.csv
# 已儲存：GpxClean\gpx_to_csv\HN武陵山莊+桃山登山山徑來回.csv
# 已儲存：GpxClean\gpx_to_csv\HN武陵桃山 (1).csv
# 已儲存：GpxClean\gpx_to_csv\HN武陵桃山 (2).csv
# 已儲存：GpxClean\gpx_to_csv\HN武陵桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN浪花桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN米羅神殿上桃山.csv
# 已儲存：GpxClean\gpx_to_csv\HN馬偕寶寶桃山單攻.csv
#
# WARNING: 以下檔案沒有 `time` 欄位，已跳過轉換：
#  - 202011 桃山單攻.gpx
#  - 桃山 (34).gpx
#  - 桃山 (52).gpx
#  - 桃山 (58).gpx
#  - 桃山 (59).gpx
#  - 桃山一日單攻 (1).gpx
#  - 桃山單攻 (1).gpx
#  - 桃山單攻 (52).gpx
#  - 桃山步道 (6).gpx
#  - 武陵桃山.gpx
#
# gpx_to_csv 資料夾中共有 536 筆資料（CSV 檔）

# %% [markdown]
# ### 水平距離計算
#
# 以簡化平面距離進行計算（適合小範圍，緯度變化不大，假設地球為平面
# 111320 是一個近似值，代表"緯度"每度約等於 111320 公尺
# 地球周長在赤道最大，越靠近極地越小，需要用 cos 隨緯度修正
#
# 緯度差，換算成公尺
# dy = (lat2 - lat1) * 111320
# 經度差，換算成公尺
# dx = (lon2 - lon1) * 111320 * cos(radians((lat1 + lat2) / 2))
#
# 畢氏定理
# distance = sqrt(dx**2 + dy**2)
# return distance

# %%
import pandas as pd
from math import cos, radians, sqrt
from pathlib import Path

def flat_distance(lat1, lon1, lat2, lon2):
    dy = (lat2 - lat1) * 111320
    dx = (lon2 - lon1) * 111320 * cos(radians((lat1 + lat2) / 2))
    return sqrt(dx**2 + dy**2)

NOTEBOOK_DIR = Path.cwd()
CSV_DIR      = NOTEBOOK_DIR / 'gpx_to_csv'
ADD_DIR      = NOTEBOOK_DIR / 'add_cum_csv'
ADD_DIR.mkdir(exist_ok=True, parents=True)

summaries     = []
skipped_files = []   # ← 用來記錄所有跳過的檔案

for csv_path in CSV_DIR.glob('*.csv'):
    out_path = ADD_DIR / csv_path.name
    # 1) 已存在就跳過
    if out_path.exists():
        skipped_files.append(csv_path.name)
        print(f"已存在，跳過：{csv_path.name}")
        continue

    # 2) 空檔、無 time 欄都跳過
    try:
        df = pd.read_csv(csv_path)
    except pd.errors.EmptyDataError:
        skipped_files.append(csv_path.name)
        print(f"警告：檔案為空 → {csv_path.name}")
        continue

    if 'time' not in df.columns:
        skipped_files.append(csv_path.name)
        print(f"警告：缺少 time 欄 → {csv_path.name}")
        continue

    # 強制轉 datetime，並去除轉換失敗的列
    df['time'] = pd.to_datetime(df['time'], errors='coerce')
    df = df.dropna(subset=['time']).sort_values('time').reset_index(drop=True)
    if df.empty:
        skipped_files.append(csv_path.name)
        print(f"警告：無有效時間資料 → {csv_path.name}")
        continue

    # 計算累積欄位
    cum_time = []; cum_dist = []; cum_up = []; cum_down = []
    total_dist = total_up = total_down = 0.0
    start_time = df.loc[0, 'time']
    last_lat, last_lon, last_ele = df.loc[0, ['lat','lon','ele']]

    for idx, row in df.iterrows():
        cum_time.append(row['time'] - start_time)
        if idx > 0:
            d = flat_distance(last_lat, last_lon, row['lat'], row['lon'])
            total_dist += d
            delta_ele = row['ele'] - last_ele
            if delta_ele > 0: total_up += delta_ele
            else:             total_down += abs(delta_ele)
        cum_dist.append(total_dist)
        cum_up.append(total_up)
        cum_down.append(total_down)
        last_lat, last_lon, last_ele = row['lat'], row['lon'], row['ele']

    df['cum_dist'] = cum_dist
    df['cum_up'] = cum_up
    df['cum_down'] = cum_down
    df['cum_time'] = cum_time

    df.to_csv(out_path, index=False, encoding='utf-8-sig')
    print(f"已另存：{out_path.relative_to(NOTEBOOK_DIR)}")

    summaries.append({
        '檔案名':            csv_path.name,
        'max累計水平距離':  cum_dist[-1],
        'max累計爬升高度':  cum_up[-1],
        'max累計下降高度':  cum_down[-1],
        'max累計花費時間':  cum_time[-1],
    })

# 輸出 summary.csv
if summaries:
    pd.DataFrame(summaries).to_csv(ADD_DIR / 'summary.csv', index=False, encoding='utf-8-sig')

# 最後列印所有跳過的檔案
if skipped_files:
    print("\n===== 跳過的檔案清單 =====")
    for name in skipped_files:
        print(f"• {name}")
else:
    print("\n沒有任何檔案被跳過。")
# Out:
# 已另存：add_cum_csv\HB0409桃山沒桃子.csv
# 已另存：add_cum_csv\HB0410桃山.csv
# 已另存：add_cum_csv\HB0521單攻桃山.csv
# 已另存：add_cum_csv\HB0829桃山.csv
# 已另存：add_cum_csv\HB1-18桃山.csv
# 已另存：add_cum_csv\HB10-15 桃山單攻.csv
# 已另存：add_cum_csv\HB1091011-桃山.csv
# 已另存：add_cum_csv\HB1091226桃山單攻.csv
# 已另存：add_cum_csv\HB111.09.25桃山單攻.csv
# 已另存：add_cum_csv\HB111.8.22桃山單攻.csv
# 已另存：add_cum_csv\HB1110115桃山⛰️.csv
# 已另存：add_cum_csv\HB112-9-24桃山單攻.csv
# 已另存：add_cum_csv\HB12.03桃山.csv
# 已另存：add_cum_csv\HB20123-9-23爬桃山爬到厭世.csv
# 已另存：add_cum_csv\HB2014-5-25單攻桃山.csv
# 已另存：add_cum_csv\HB20200418 桃山.csv
# 警告：檔案為空 → HB202011 桃山單攻.csv
# 已另存：add_cum_csv\HB20201212 桃山.csv
# 已另存：add_cum_csv\HB2021-11-25 武陵桃山上行.csv
# 已另存：add_cum_csv\HB2021-11-28 桃山.csv
# 已另存：add_cum_csv\HB2021-11-7 桃山.csv
# 已另存：add_cum_csv\HB2021-12-11 桃山.csv
# 已另存：add_cum_csv\HB2021-12-20 桃山單攻.csv
# 已另存：add_cum_csv\HB2021-9-26 桃山單攻.csv
# 已另存：add_cum_csv\HB20210320_桃山單攻.csv
# 已另存：add_cum_csv\HB20210927桃山單攻.csv
# 已另存：add_cum_csv\HB20211016-桃山單攻.csv
# 已另存：add_cum_csv\HB2022-10-08 桃山.csv
# 已另存：add_cum_csv\HB2022-6-19 桃山.csv
# 已另存：add_cum_csv\HB2022-6-25 桃山.csv
# 已另存：add_cum_csv\HB2022-6-3 桃山單攻.csv
# 已另存：add_cum_csv\HB2022-8-28 桃山單攻.csv
# 已另存：add_cum_csv\HB2022-9-10 桃山.csv
# 已另存：add_cum_csv\HB20220703_桃山單攻.csv
# 已另存：add_cum_csv\HB20220710 一日桃山.csv
# 已另存：add_cum_csv\HB20220910中秋自虐桃山.csv
# 已另存：add_cum_csv\HB2022100 重裝16kg上桃山.csv
# 已另存：add_cum_csv\HB20221001桃山.csv
# 已另存：add_cum_csv\HB2022桃山.csv
# 已另存：add_cum_csv\HB2023-05-05 桃山單攻.csv
# 已另存：add_cum_csv\HB2023-054桃山.csv
# 已另存：add_cum_csv\HB2023-0617 桃山一日單攻成功.csv
# 已另存：add_cum_csv\HB2023-09-16桃山單攻.csv
# 已另存：add_cum_csv\HB2023-09-23 一日桃山.csv
# 已另存：add_cum_csv\HB2023-10-15桃山單攻.csv
# 已另存：add_cum_csv\HB2023-10-2 桃山.csv
# 已另存：add_cum_csv\HB2023-10-27 桃山.csv
# 已另存：add_cum_csv\HB2023-10-28 桃山單攻.csv
# 已另存：add_cum_csv\HB2023-10-9 桃山一日遊.csv
# 已另存：add_cum_csv\HB2023-11-25 桃山.csv
# 已另存：add_cum_csv\HB2023-11-26 桃山單攻 (1).csv
# 已另存：add_cum_csv\HB2023-11-26 桃山單攻.csv
# 已另存：add_cum_csv\HB2023-11-4 桃山一日單攻.csv
# 已另存：add_cum_csv\HB2023-12-31 桃山.csv
# 已另存：add_cum_csv\HB2023-3-23 桃山.csv
# 已另存：add_cum_csv\HB2023-4-3 桃山單攻.csv
# 已另存：add_cum_csv\HB2023-4-30 第一座百岳 桃山單攻.csv
# 已另存：add_cum_csv\HB2023-5-27 桃山.csv
# 已另存：add_cum_csv\HB2023-6-10 桃山單攻.csv
# 已另存：add_cum_csv\HB2023-6-23 桃山.csv
# 已另存：add_cum_csv\HB2023-6-8 桃山單攻.csv
# 已另存：add_cum_csv\HB2023-7-11 桃山.csv
# 已另存：add_cum_csv\HB2023-7-11桃山.csv
# 已另存：add_cum_csv\HB2023-7-23 桃山單攻 (1).csv
# 已另存：add_cum_csv\HB2023-7-23 桃山單攻.csv
# 已另存：add_cum_csv\HB2023-7-5 桃山武陵.csv
# 已另存：add_cum_csv\HB2023-8-12 桃山單攻.csv
# 已另存：add_cum_csv\HB2023-8-13 桃山.csv
# 已另存：add_cum_csv\HB2023-8-13 重裝桃山訓.csv
# 已另存：add_cum_csv\HB2023-8-19 桃山.csv
# 已另存：add_cum_csv\HB2023-8-26 桃山.csv
# 已另存：add_cum_csv\HB2023-8-27 桃山單攻.csv
# 已另存：add_cum_csv\HB2023-9-24 桃山單攻練腿.csv
# 已另存：add_cum_csv\HB2023.12.27桃山一日單攻.csv
# 已另存：add_cum_csv\HB2023.9.17桃山單攻.csv
# 已另存：add_cum_csv\HB20230610桃山.csv
# 已另存：add_cum_csv\HB20230711 桃山單攻.csv
# 已另存：add_cum_csv\HB20231108桃山輕鬆自在行.csv
# 已另存：add_cum_csv\HB20231213-桃山單攻.csv
# 已另存：add_cum_csv\HB2024-02-02 武陵第一秀。桃山.csv
# 已另存：add_cum_csv\HB2024-0608桃山單攻.csv
# 已另存：add_cum_csv\HB2024-1-29 桃山.csv
# 已另存：add_cum_csv\HB2024-10-13桃山單攻看日出.csv
# 已另存：add_cum_csv\HB2024-10-22 桃山.csv
# 已另存：add_cum_csv\HB2024-10-6 桃山步道.csv
# 已另存：add_cum_csv\HB2024-11-09 單攻桃山.csv
# 已另存：add_cum_csv\HB2024-11-23桃山.csv
# 已另存：add_cum_csv\HB2024-11-24 ㄧ日桃山.csv
# 已另存：add_cum_csv\HB2024-11-24 小桃山猴子偷桃.csv
# 已另存：add_cum_csv\HB2024-11-24 桃山單攻.csv
# 已另存：add_cum_csv\HB2024-11-25 桃山.csv
# 已另存：add_cum_csv\HB2024-11-9 桃山.csv
# 已另存：add_cum_csv\HB2024-12-1 桃山單攻.csv
# 已另存：add_cum_csv\HB2024-12-14 輕裝登山_桃山步道.csv
# 已另存：add_cum_csv\HB2024-12-15 晚間輕裝登山_桃山步道.csv
# 已另存：add_cum_csv\HB2024-12-22 桃山.csv
# 已另存：add_cum_csv\HB2024-12-22 桃山單攻.csv
# 已另存：add_cum_csv\HB2024-12-22 桃山步道.csv
# 已另存：add_cum_csv\HB2024-12-22_桃山.csv
# 已另存：add_cum_csv\HB2024-12-23 晨間輕裝登山_桃山步道.csv
# 已另存：add_cum_csv\HB2024-12-28 晚間輕裝登山_桃山步道.csv
# 已另存：add_cum_csv\HB2024-12-3 武陵農場桃山步道.csv
# 已另存：add_cum_csv\HB2024-12-31桃山.csv
# 已另存：add_cum_csv\HB2024-12-6 晨間輕裝上桃山.csv
# 已另存：add_cum_csv\HB2024-12-7 單攻桃山、池友山.csv
# 已另存：add_cum_csv\HB2024-12-7 晨間輕裝登山_桃山步道.csv
# 已另存：add_cum_csv\HB2024-12-8 晚間輕裝登山_桃山.csv
# 已另存：add_cum_csv\HB2024-12-8 桃山單攻.csv
# 已另存：add_cum_csv\HB2024-2-23 桃山單攻去.csv
# 已另存：add_cum_csv\HB2024-3-15 晨間重裝桃山.csv
# 已另存：add_cum_csv\HB2024-3-21桃山步道.csv
# 已另存：add_cum_csv\HB2024-3-30 登桃山.csv
# 已另存：add_cum_csv\HB2024-5-19桃山單攻.csv
# 已另存：add_cum_csv\HB2024-5-5 桃山一日.csv
# 已另存：add_cum_csv\HB2024-6-16 桃山.csv
# 已另存：add_cum_csv\HB2024-6-17 桃山.csv
# 已另存：add_cum_csv\HB2024-7-1 桃山單攻🍑.csv
# 已另存：add_cum_csv\HB2024-7-19 桃山步道.csv
# 已另存：add_cum_csv\HB2024-7-7  武陵桃山.csv
# 已另存：add_cum_csv\HB2024-8-10 桃山.csv
# 已另存：add_cum_csv\HB2024-8-11 晨間輕裝登山_桃山步道.csv
# 已另存：add_cum_csv\HB2024-8-24 桃山單攻.csv
# 已另存：add_cum_csv\HB2024-9-1 晨間輕裝登山_桃山步道.csv
# 已另存：add_cum_csv\HB2024-9-1 桃山.csv
# 已另存：add_cum_csv\HB2024-9-1 桃山單攻.csv
# 已另存：add_cum_csv\HB2024-9-18 午後輕裝登山_桃山步道.csv
# 已另存：add_cum_csv\HB2024.12.16  桃山.csv
# 已另存：add_cum_csv\HB20240214桃山.csv
# 已另存：add_cum_csv\HB20240303 與柯桃山初百岳.csv
# 已另存：add_cum_csv\HB20240303阿姿第一座百岳桃山.csv
# 已另存：add_cum_csv\HB20240421桃山.csv
# 已另存：add_cum_csv\HB20240615桃山.csv
# 已另存：add_cum_csv\HB202408-10 桃山之行 硬啊.csv
# 已另存：add_cum_csv\HB20240917桃山.csv
# 已另存：add_cum_csv\HB20241012桃山單攻.csv
# 已另存：add_cum_csv\HB20241029桃山單攻.csv
# 已另存：add_cum_csv\HB2025-04-04 桃山.csv
# 已另存：add_cum_csv\HB2025-05-17 桃山單攻.csv
# 已另存：add_cum_csv\HB2025-06-23 晨間輕裝登山 _ 2025-06-23 桃山單攻.csv
# 已另存：add_cum_csv\HB2025-1-26 輕裝桃山.csv
# 已另存：add_cum_csv\HB2025-2-21 晨間重裝登山_桃山步道.csv
# 已另存：add_cum_csv\HB2025-4-12 晨間輕裝登山_桃山.csv
# 已另存：add_cum_csv\HB2025-4-4 桃山一日單攻.csv
# 已另存：add_cum_csv\HB2025-5-17 桃山單攻.csv
# 已另存：add_cum_csv\HB2025-5-18  桃山單攻.csv
# 已另存：add_cum_csv\HB2025-5-18 桃山單攻.csv
# 已另存：add_cum_csv\HB2025-5-20 登桃山一日遊.csv
# 已另存：add_cum_csv\HB2025-5-3 大鵰桃山單攻.csv
# 已另存：add_cum_csv\HB2025-5-30 端午節桃山單攻.csv
# 已另存：add_cum_csv\HB2025-5-31端午節桃山單攻.csv
# 已另存：add_cum_csv\HB2025-6-10 桃山單攻.csv
# 已另存：add_cum_csv\HB2025-6-15 桃山12刷.csv
# 已另存：add_cum_csv\HB2025-6-19 桃山單攻.csv
# 已另存：add_cum_csv\HB2025-6-23 桃山單攻.csv
# 已另存：add_cum_csv\HB2025-6-29 桃山.csv
# 已另存：add_cum_csv\HB2025-6-8 桃山11刷.csv
# 已另存：add_cum_csv\HB240328桃山.csv
# 已另存：add_cum_csv\HB5-25-25 晨間輕裝登山 桃山瀑佈.csv
# 已另存：add_cum_csv\HB713桃山單攻.csv
# 已另存：add_cum_csv\HB8-11-2023單登桃山.csv
# 已另存：add_cum_csv\HBAmouter單攻桃山.csv
# 已另存：add_cum_csv\HBJayden-桃山.csv
# 已另存：add_cum_csv\HB「桃山」單攻.csv
# 已另存：add_cum_csv\HB一日桃山 (1).csv
# 已另存：add_cum_csv\HB一日桃山 (2).csv
# 已另存：add_cum_csv\HB一日桃山.csv
# 已另存：add_cum_csv\HB一日桃山單攻.csv
# 已另存：add_cum_csv\HB一日桃山散步行.csv
# 已另存：add_cum_csv\HB初百岳-桃山.csv
# 已另存：add_cum_csv\HB台中。和平。武陵桃山步道.csv
# 已另存：add_cum_csv\HB單攻桃山 (1).csv
# 已另存：add_cum_csv\HB單攻桃山 (2).csv
# 已另存：add_cum_csv\HB單攻桃山.csv
# 已另存：add_cum_csv\HB單攻百岳No.48 桃山.csv
# 已另存：add_cum_csv\HB大霸尖山行前訓練-單攻桃山.csv
# 已另存：add_cum_csv\HB我的第一座百岳-桃山.csv
# 已另存：add_cum_csv\HB新竹台中交界_桃山一日單登.csv
# 已另存：add_cum_csv\HB晨間輕裝登山 桃山.csv
# 已另存：add_cum_csv\HB桃山 (1).csv
# 已另存：add_cum_csv\HB桃山 (10).csv
# 已另存：add_cum_csv\HB桃山 (11).csv
# 已另存：add_cum_csv\HB桃山 (12).csv
# 已另存：add_cum_csv\HB桃山 (13).csv
# 已另存：add_cum_csv\HB桃山 (14).csv
# 已另存：add_cum_csv\HB桃山 (15).csv
# 已另存：add_cum_csv\HB桃山 (16).csv
# 已另存：add_cum_csv\HB桃山 (17).csv
# 已另存：add_cum_csv\HB桃山 (18).csv
# 已另存：add_cum_csv\HB桃山 (19).csv
# 已另存：add_cum_csv\HB桃山 (2).csv
# 已另存：add_cum_csv\HB桃山 (20).csv
# 已另存：add_cum_csv\HB桃山 (21).csv
# 已另存：add_cum_csv\HB桃山 (22).csv
# 已另存：add_cum_csv\HB桃山 (23).csv
# 已另存：add_cum_csv\HB桃山 (24).csv
# 已另存：add_cum_csv\HB桃山 (25).csv
# 已另存：add_cum_csv\HB桃山 (26).csv
# 已另存：add_cum_csv\HB桃山 (27).csv
# 已另存：add_cum_csv\HB桃山 (28).csv
# 已另存：add_cum_csv\HB桃山 (29).csv
# 已另存：add_cum_csv\HB桃山 (3).csv
# 已另存：add_cum_csv\HB桃山 (30).csv
# 已另存：add_cum_csv\HB桃山 (31).csv
# 已另存：add_cum_csv\HB桃山 (32).csv
# 已另存：add_cum_csv\HB桃山 (33).csv
# 警告：檔案為空 → HB桃山 (34).csv
# 已另存：add_cum_csv\HB桃山 (35).csv
# 已另存：add_cum_csv\HB桃山 (36).csv
# 已另存：add_cum_csv\HB桃山 (37).csv
# 已另存：add_cum_csv\HB桃山 (38).csv
# 已另存：add_cum_csv\HB桃山 (39).csv
# 已另存：add_cum_csv\HB桃山 (4).csv
# 已另存：add_cum_csv\HB桃山 (40).csv
# 已另存：add_cum_csv\HB桃山 (41).csv
# 已另存：add_cum_csv\HB桃山 (42).csv
# 已另存：add_cum_csv\HB桃山 (43).csv
# 已另存：add_cum_csv\HB桃山 (44).csv
# 已另存：add_cum_csv\HB桃山 (45).csv
# 已另存：add_cum_csv\HB桃山 (46).csv
# 已另存：add_cum_csv\HB桃山 (47).csv
# 已另存：add_cum_csv\HB桃山 (48).csv
# 已另存：add_cum_csv\HB桃山 (49).csv
# 已另存：add_cum_csv\HB桃山 (5).csv
# 已另存：add_cum_csv\HB桃山 (50).csv
# 已另存：add_cum_csv\HB桃山 (51).csv
# 警告：檔案為空 → HB桃山 (52).csv
# 已另存：add_cum_csv\HB桃山 (53).csv
# 已另存：add_cum_csv\HB桃山 (54).csv
# 已另存：add_cum_csv\HB桃山 (55).csv
# 已另存：add_cum_csv\HB桃山 (56).csv
# 已另存：add_cum_csv\HB桃山 (57).csv
# 警告：檔案為空 → HB桃山 (58).csv
# 警告：檔案為空 → HB桃山 (59).csv
# 已另存：add_cum_csv\HB桃山 (6).csv
# 已另存：add_cum_csv\HB桃山 (60).csv
# 已另存：add_cum_csv\HB桃山 (61).csv
# 已另存：add_cum_csv\HB桃山 (7).csv
# 已另存：add_cum_csv\HB桃山 (8).csv
# 已另存：add_cum_csv\HB桃山 (9).csv
# 已另存：add_cum_csv\HB桃山 克啦業.csv
# 已另存：add_cum_csv\HB桃山.csv
# 已另存：add_cum_csv\HB桃山1126.csv
# 已另存：add_cum_csv\HB桃山2.1K野餐20240316.csv
# 已另存：add_cum_csv\HB桃山20210411.csv
# 已另存：add_cum_csv\HB桃山2023-4-27.csv
# 警告：檔案為空 → HB桃山一日單攻 (1).csv
# 已另存：add_cum_csv\HB桃山一日單攻 (2).csv
# 已另存：add_cum_csv\HB桃山一日單攻.csv
# 已另存：add_cum_csv\HB桃山一日單攻_20220416.csv
# 已另存：add_cum_csv\HB桃山不要再去了.csv
# 已另存：add_cum_csv\HB桃山單.csv
# 警告：檔案為空 → HB桃山單攻 (1).csv
# 已另存：add_cum_csv\HB桃山單攻 (10).csv
# 已另存：add_cum_csv\HB桃山單攻 (11).csv
# 已另存：add_cum_csv\HB桃山單攻 (12).csv
# 已另存：add_cum_csv\HB桃山單攻 (13).csv
# 已另存：add_cum_csv\HB桃山單攻 (14).csv
# 已另存：add_cum_csv\HB桃山單攻 (15).csv
# 已另存：add_cum_csv\HB桃山單攻 (16).csv
# 已另存：add_cum_csv\HB桃山單攻 (17).csv
# 已另存：add_cum_csv\HB桃山單攻 (18).csv
# 已另存：add_cum_csv\HB桃山單攻 (19).csv
# 已另存：add_cum_csv\HB桃山單攻 (2).csv
# 已另存：add_cum_csv\HB桃山單攻 (20).csv
# 已另存：add_cum_csv\HB桃山單攻 (21).csv
# 已另存：add_cum_csv\HB桃山單攻 (22).csv
# 已另存：add_cum_csv\HB桃山單攻 (23).csv
# 已另存：add_cum_csv\HB桃山單攻 (24).csv
# 已另存：add_cum_csv\HB桃山單攻 (25).csv
# 已另存：add_cum_csv\HB桃山單攻 (26).csv
# 已另存：add_cum_csv\HB桃山單攻 (27).csv
# 已另存：add_cum_csv\HB桃山單攻 (28).csv
# 已另存：add_cum_csv\HB桃山單攻 (29).csv
# 已另存：add_cum_csv\HB桃山單攻 (3).csv
# 已另存：add_cum_csv\HB桃山單攻 (30).csv
# 已另存：add_cum_csv\HB桃山單攻 (31).csv
# 已另存：add_cum_csv\HB桃山單攻 (32).csv
# 已另存：add_cum_csv\HB桃山單攻 (33).csv
# 已另存：add_cum_csv\HB桃山單攻 (34).csv
# 已另存：add_cum_csv\HB桃山單攻 (35).csv
# 已另存：add_cum_csv\HB桃山單攻 (36).csv
# 已另存：add_cum_csv\HB桃山單攻 (37).csv
# 已另存：add_cum_csv\HB桃山單攻 (38).csv
# 已另存：add_cum_csv\HB桃山單攻 (39).csv
# 已另存：add_cum_csv\HB桃山單攻 (4).csv
# 已另存：add_cum_csv\HB桃山單攻 (40).csv
# 已另存：add_cum_csv\HB桃山單攻 (41).csv
# 已另存：add_cum_csv\HB桃山單攻 (42).csv
# 已另存：add_cum_csv\HB桃山單攻 (43).csv
# 已另存：add_cum_csv\HB桃山單攻 (44).csv
# 已另存：add_cum_csv\HB桃山單攻 (45).csv
# 已另存：add_cum_csv\HB桃山單攻 (46).csv
# 已另存：add_cum_csv\HB桃山單攻 (47).csv
# 已另存：add_cum_csv\HB桃山單攻 (48).csv
# 已另存：add_cum_csv\HB桃山單攻 (49).csv
# 已另存：add_cum_csv\HB桃山單攻 (5).csv
# 已另存：add_cum_csv\HB桃山單攻 (50).csv
# 已另存：add_cum_csv\HB桃山單攻 (51).csv
# 警告：檔案為空 → HB桃山單攻 (52).csv
# 已另存：add_cum_csv\HB桃山單攻 (6).csv
# 已另存：add_cum_csv\HB桃山單攻 (7).csv
# 已另存：add_cum_csv\HB桃山單攻 (8).csv
# 已另存：add_cum_csv\HB桃山單攻 (9).csv
# 已另存：add_cum_csv\HB桃山單攻.csv
# 已另存：add_cum_csv\HB桃山單攻2022-07-22.csv
# 已另存：add_cum_csv\HB桃山單攻20220730.csv
# 已另存：add_cum_csv\HB桃山單攻20240120.csv
# 已另存：add_cum_csv\HB桃山單攻20240714.csv
# 已另存：add_cum_csv\HB桃山單攻無傷完登.csv
# 已另存：add_cum_csv\HB桃山單日單攻.csv
# 已另存：add_cum_csv\HB桃山單登 (1).csv
# 已另存：add_cum_csv\HB桃山單登.csv
# 已另存：add_cum_csv\HB桃山完工.csv
# 已另存：add_cum_csv\HB桃山小辣椒.csv
# 已另存：add_cum_csv\HB桃山步道 (1).csv
# 已另存：add_cum_csv\HB桃山步道 (2).csv
# 已另存：add_cum_csv\HB桃山步道 (3).csv
# 已另存：add_cum_csv\HB桃山步道 (4).csv
# 已另存：add_cum_csv\HB桃山步道 (5).csv
# 警告：檔案為空 → HB桃山步道 (6).csv
# 已另存：add_cum_csv\HB桃山步道.csv
# 已另存：add_cum_csv\HB桃山登山 (1).csv
# 已另存：add_cum_csv\HB桃山登山.csv
# 已另存：add_cum_csv\HB桃山百岳.csv
# 已另存：add_cum_csv\HB桃山第八刷20240511.csv
# 已另存：add_cum_csv\HB桃山第十刷.csv
# 已另存：add_cum_csv\HB桃山行.csv
# 已另存：add_cum_csv\HB桃山軟爛行程.csv
# 已另存：add_cum_csv\HB桃山🍑一日單攻.csv
# 已另存：add_cum_csv\HB桃山，2023-11-4 晚間輕裝.csv
# 已另存：add_cum_csv\HB桃山，go.go.go.csv
# 已另存：add_cum_csv\HB桃山￼.csv
# 已另存：add_cum_csv\HB武陵一秀 - 桃山.csv
# 已另存：add_cum_csv\HB武陵桃山 (1).csv
# 警告：檔案為空 → HB武陵桃山.csv
# 已另存：add_cum_csv\HB武陵農場桃山.csv
# 已另存：add_cum_csv\HB百岳-桃山 (1).csv
# 已另存：add_cum_csv\HB百岳-桃山.csv
# 已另存：add_cum_csv\HB石猴桃山沼平.csv
# 已另存：add_cum_csv\HB聖誕桃山.csv
# 已另存：add_cum_csv\HN0521桃山單攻.csv
# 已另存：add_cum_csv\HN1100514桃山.csv
# 已另存：add_cum_csv\HN1110925桃山.csv
# 已另存：add_cum_csv\HN1120521桃山單登.csv
# 已另存：add_cum_csv\HN1130920單攻桃山.csv
# 已另存：add_cum_csv\HN13825桃山單攻.csv
# 已另存：add_cum_csv\HN2017-04-30 桃山單攻.csv
# 已另存：add_cum_csv\HN20190914桃山單攻.csv
# 已另存：add_cum_csv\HN20200716 - 一日單攻桃山.csv
# 已另存：add_cum_csv\HN20201031桃山.csv
# 已另存：add_cum_csv\HN2020322桃山單攻.csv
# 已另存：add_cum_csv\HN2021-03-13_桃山一日單攻.csv
# 已另存：add_cum_csv\HN2021.04.17桃山單攻.csv
# 已另存：add_cum_csv\HN20210321 桃山.csv
# 已另存：add_cum_csv\HN20210814桃山單攻.csv
# 已另存：add_cum_csv\HN20211205桃山.csv
# 已另存：add_cum_csv\HN20211210桃山單攻.csv
# 已另存：add_cum_csv\HN2021桃山.csv
# 已另存：add_cum_csv\HN2022.12.24 桃山.csv
# 已另存：add_cum_csv\HN20220404桃山單攻.csv
# 已另存：add_cum_csv\HN20220414桃山單攻.csv
# 已另存：add_cum_csv\HN20220704 桃山單攻.csv
# 已另存：add_cum_csv\HN20220806 桃山.csv
# 已另存：add_cum_csv\HN20221121桃山單攻.csv
# 已另存：add_cum_csv\HN20221211 桃山單攻.csv
# 已另存：add_cum_csv\HN2023-04-22_附中桃山單攻.csv
# 已另存：add_cum_csv\HN20231014 - 15 米羅佐得寒上桃山(米佐桃縱走).csv
# 已另存：add_cum_csv\HN20231026桃山.csv
# 已另存：add_cum_csv\HN2024.12.07單攻桃山初體驗.csv
# 已另存：add_cum_csv\HN20240902 桃山單攻.csv
# 已另存：add_cum_csv\HN20250517-桃山.csv
# 已另存：add_cum_csv\HN20251221桃山單攻嗚嗚嗚.csv
# 已另存：add_cum_csv\HN228桃山單攻GO.csv
# 已另存：add_cum_csv\HN240517桃山單攻.csv
# 已另存：add_cum_csv\HNBENTANG桃山單攻.csv
# 已另存：add_cum_csv\HN一日桃山 (1).csv
# 已另存：add_cum_csv\HN一日桃山.csv
# 已另存：add_cum_csv\HN一日桃山單攻.csv
# 已另存：add_cum_csv\HN佐得寒喀桃山武陵.csv
# 已另存：add_cum_csv\HN包愛罐帶小孩桃山單攻.csv
# 已另存：add_cum_csv\HN單攻桃山 (1).csv
# 已另存：add_cum_csv\HN單攻桃山.csv
# 已另存：add_cum_csv\HN單攻桃山（上）.csv
# 已另存：add_cum_csv\HN小魚桃山生日趴.csv
# 已另存：add_cum_csv\HN慢速單攻桃山.csv
# 已另存：add_cum_csv\HN桃山 (1).csv
# 已另存：add_cum_csv\HN桃山 (10).csv
# 已另存：add_cum_csv\HN桃山 (11).csv
# 已另存：add_cum_csv\HN桃山 (12).csv
# 已另存：add_cum_csv\HN桃山 (13).csv
# 已另存：add_cum_csv\HN桃山 (14).csv
# 已另存：add_cum_csv\HN桃山 (15).csv
# 已另存：add_cum_csv\HN桃山 (16).csv
# 已另存：add_cum_csv\HN桃山 (17).csv
# 已另存：add_cum_csv\HN桃山 (18).csv
# 已另存：add_cum_csv\HN桃山 (19).csv
# 已另存：add_cum_csv\HN桃山 (2).csv
# 已另存：add_cum_csv\HN桃山 (20).csv
# 已另存：add_cum_csv\HN桃山 (21).csv
# 已另存：add_cum_csv\HN桃山 (22).csv
# 已另存：add_cum_csv\HN桃山 (23).csv
# 已另存：add_cum_csv\HN桃山 (24).csv
# 已另存：add_cum_csv\HN桃山 (25).csv
# 已另存：add_cum_csv\HN桃山 (26).csv
# 已另存：add_cum_csv\HN桃山 (27).csv
# 已另存：add_cum_csv\HN桃山 (28).csv
# 已另存：add_cum_csv\HN桃山 (29).csv
# 已另存：add_cum_csv\HN桃山 (3).csv
# 已另存：add_cum_csv\HN桃山 (30).csv
# 已另存：add_cum_csv\HN桃山 (31).csv
# 已另存：add_cum_csv\HN桃山 (32).csv
# 已另存：add_cum_csv\HN桃山 (33).csv
# 已另存：add_cum_csv\HN桃山 (34).csv
# 已另存：add_cum_csv\HN桃山 (35).csv
# 已另存：add_cum_csv\HN桃山 (36).csv
# 已另存：add_cum_csv\HN桃山 (37).csv
# 已另存：add_cum_csv\HN桃山 (38).csv
# 已另存：add_cum_csv\HN桃山 (39).csv
# 已另存：add_cum_csv\HN桃山 (4).csv
# 已另存：add_cum_csv\HN桃山 (40).csv
# 已另存：add_cum_csv\HN桃山 (41).csv
# 已另存：add_cum_csv\HN桃山 (42).csv
# 已另存：add_cum_csv\HN桃山 (43).csv
# 已另存：add_cum_csv\HN桃山 (44).csv
# 已另存：add_cum_csv\HN桃山 (45).csv
# 已另存：add_cum_csv\HN桃山 (46).csv
# 已另存：add_cum_csv\HN桃山 (47).csv
# 已另存：add_cum_csv\HN桃山 (48).csv
# 已另存：add_cum_csv\HN桃山 (49).csv
# 已另存：add_cum_csv\HN桃山 (5).csv
# 已另存：add_cum_csv\HN桃山 (6).csv
# 已另存：add_cum_csv\HN桃山 (7).csv
# 已另存：add_cum_csv\HN桃山 (8).csv
# 已另存：add_cum_csv\HN桃山 (9).csv
# 已另存：add_cum_csv\HN桃山(上).csv
# 已另存：add_cum_csv\HN桃山.csv
# 已另存：add_cum_csv\HN桃山1.5K.csv
# 已另存：add_cum_csv\HN桃山1111008 (1).csv
# 已另存：add_cum_csv\HN桃山1111008.csv
# 已另存：add_cum_csv\HN桃山1125.csv
# 已另存：add_cum_csv\HN桃山1日單攻.csv
# 已另存：add_cum_csv\HN桃山D1.csv
# 已另存：add_cum_csv\HN桃山一日單攻 (1).csv
# 已另存：add_cum_csv\HN桃山一日單攻 (2).csv
# 已另存：add_cum_csv\HN桃山一日單攻 (3).csv
# 已另存：add_cum_csv\HN桃山一日單攻 (4).csv
# 已另存：add_cum_csv\HN桃山一日單攻 (5).csv
# 已另存：add_cum_csv\HN桃山一日單攻 (6).csv
# 已另存：add_cum_csv\HN桃山一日單攻 (7).csv
# 已另存：add_cum_csv\HN桃山一日單攻 (8).csv
# 已另存：add_cum_csv\HN桃山一日單攻 (9).csv
# 已另存：add_cum_csv\HN桃山一日單攻.csv
# 已另存：add_cum_csv\HN桃山一日單攻！.csv
# 已另存：add_cum_csv\HN桃山上吃粽子.csv
# 已另存：add_cum_csv\HN桃山上山.csv
# 已另存：add_cum_csv\HN桃山出大景.csv
# 已另存：add_cum_csv\HN桃山單供20230625.csv
# 已另存：add_cum_csv\HN桃山單攻 (1).csv
# 已另存：add_cum_csv\HN桃山單攻 (10).csv
# 已另存：add_cum_csv\HN桃山單攻 (11).csv
# 已另存：add_cum_csv\HN桃山單攻 (12).csv
# 已另存：add_cum_csv\HN桃山單攻 (13).csv
# 已另存：add_cum_csv\HN桃山單攻 (14).csv
# 已另存：add_cum_csv\HN桃山單攻 (15).csv
# 已另存：add_cum_csv\HN桃山單攻 (16).csv
# 已另存：add_cum_csv\HN桃山單攻 (17).csv
# 已另存：add_cum_csv\HN桃山單攻 (18).csv
# 已另存：add_cum_csv\HN桃山單攻 (19).csv
# 已另存：add_cum_csv\HN桃山單攻 (2).csv
# 已另存：add_cum_csv\HN桃山單攻 (20).csv
# 已另存：add_cum_csv\HN桃山單攻 (21).csv
# 已另存：add_cum_csv\HN桃山單攻 (22).csv
# 已另存：add_cum_csv\HN桃山單攻 (23).csv
# 已另存：add_cum_csv\HN桃山單攻 (24).csv
# C:\Users\Pin\AppData\Local\Temp\ipykernel_17840\2703390695.py:40: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['time'] = pd.to_datetime(df['time'], errors='coerce')
# 已另存：add_cum_csv\HN桃山單攻 (25).csv
# 已另存：add_cum_csv\HN桃山單攻 (26).csv
# 已另存：add_cum_csv\HN桃山單攻 (27).csv
# 已另存：add_cum_csv\HN桃山單攻 (28).csv
# 已另存：add_cum_csv\HN桃山單攻 (29).csv
# 已另存：add_cum_csv\HN桃山單攻 (3).csv
# 已另存：add_cum_csv\HN桃山單攻 (30).csv
# 已另存：add_cum_csv\HN桃山單攻 (31).csv
# 已另存：add_cum_csv\HN桃山單攻 (32).csv
# 已另存：add_cum_csv\HN桃山單攻 (33).csv
# 已另存：add_cum_csv\HN桃山單攻 (34).csv
# 已另存：add_cum_csv\HN桃山單攻 (35).csv
# 已另存：add_cum_csv\HN桃山單攻 (36).csv
# 已另存：add_cum_csv\HN桃山單攻 (37).csv
# 已另存：add_cum_csv\HN桃山單攻 (38).csv
# 已另存：add_cum_csv\HN桃山單攻 (39).csv
# 已另存：add_cum_csv\HN桃山單攻 (4).csv
# 已另存：add_cum_csv\HN桃山單攻 (40).csv
# 已另存：add_cum_csv\HN桃山單攻 (41).csv
# 已另存：add_cum_csv\HN桃山單攻 (42).csv
# 已另存：add_cum_csv\HN桃山單攻 (43).csv
# 已另存：add_cum_csv\HN桃山單攻 (44).csv
# 已另存：add_cum_csv\HN桃山單攻 (45).csv
# 已另存：add_cum_csv\HN桃山單攻 (46).csv
# 已另存：add_cum_csv\HN桃山單攻 (47).csv
# 已另存：add_cum_csv\HN桃山單攻 (48).csv
# 已另存：add_cum_csv\HN桃山單攻 (49).csv
# 已另存：add_cum_csv\HN桃山單攻 (5).csv
# 已另存：add_cum_csv\HN桃山單攻 (50).csv
# 已另存：add_cum_csv\HN桃山單攻 (6).csv
# 已另存：add_cum_csv\HN桃山單攻 (7).csv
# 已另存：add_cum_csv\HN桃山單攻 (8).csv
# 已另存：add_cum_csv\HN桃山單攻 (9).csv
# 已另存：add_cum_csv\HN桃山單攻 全程.csv
# 已另存：add_cum_csv\HN桃山單攻(原路去回).csv
# 已另存：add_cum_csv\HN桃山單攻.csv
# 已另存：add_cum_csv\HN桃山單攻1101104.csv
# 已另存：add_cum_csv\HN桃山單攻20201025.csv
# 已另存：add_cum_csv\HN桃山單攻20210814.csv
# 已另存：add_cum_csv\HN桃山單攻20241208.csv
# 已另存：add_cum_csv\HN桃山單攻230610.csv
# 已另存：add_cum_csv\HN桃山單攻一日遊.csv
# 已另存：add_cum_csv\HN桃山單攻武陵山莊出發.csv
# 已另存：add_cum_csv\HN桃山單登.csv
# 已另存：add_cum_csv\HN桃山往返.csv
# 已另存：add_cum_csv\HN桃山快樂腳.csv
# 已另存：add_cum_csv\HN桃山慢速單攻.csv
# 已另存：add_cum_csv\HN桃山步道 (1).csv
# 已另存：add_cum_csv\HN桃山步道 (2).csv
# 已另存：add_cum_csv\HN桃山步道.csv
# 已另存：add_cum_csv\HN桃山肉腳單.csv
# 已另存：add_cum_csv\HN桃山處女團.csv
# 已另存：add_cum_csv\HN桃山陡上之旅.csv
# 已另存：add_cum_csv\HN桃山雪季單攻.csv
# 已另存：add_cum_csv\HN桃山（單攻）.csv
# 已另存：add_cum_csv\HN武陵山莊+桃山登山山徑來回.csv
# 已另存：add_cum_csv\HN武陵桃山 (1).csv
# 已另存：add_cum_csv\HN武陵桃山 (2).csv
# 已另存：add_cum_csv\HN武陵桃山.csv
# 已另存：add_cum_csv\HN浪花桃山.csv
# 已另存：add_cum_csv\HN米羅神殿上桃山.csv
# 已另存：add_cum_csv\HN馬偕寶寶桃山單攻.csv
#
# ===== 跳過的檔案清單 =====
# • HB202011 桃山單攻.csv
# • HB桃山 (34).csv
# • HB桃山 (52).csv
# • HB桃山 (58).csv
# • HB桃山 (59).csv
# • HB桃山一日單攻 (1).csv
# • HB桃山單攻 (1).csv
# • HB桃山單攻 (52).csv
# • HB桃山步道 (6).csv
# • HB武陵桃山.csv

# %%
# 536 筆資料中，有 9 筆異常，剩下527 筆
# 統計 add_cum_csv 資料夾中 CSV 檔案數
added_files = list(ADD_DIR.glob('*.csv'))
print(f"add_cum_csv 資料夾中共有 {len(added_files)} 筆 CSV 檔")
# Out:
# add_cum_csv 資料夾中共有 527 筆 CSV 檔
